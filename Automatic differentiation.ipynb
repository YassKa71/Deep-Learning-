# %% [markdown]
# # Lab session 1 & 2: Introduction to PyTorch and Automatic Differentiation
#
# Authors: [pierre.tandeo@imt-atlantique.fr](pierre.tandeo@imt-atlantique.fr) and [lucas.drumetz@imt-atlantique.fr](lucas.drumetz@imt-atlantique.fr)
#
# Year: 2023-2024

# %% [markdown]
# The aim of this practice is to explain $y$ (output variable) as a function of one or several $x$ (input variables) using neural networks. Here, $x$ are continuous and $y$ can be continuous (*regression*) or discrete (*classification*). These 2 aspects are treated in the deep learning framework. Both linear and nonlinear cases will be covered in this lab session.
#
# We use the PyTorch library to implement deep learning architectures. This interface has the following characteristics:
# - it is using tensors, kind of arrays that can be easily manipulated by GPUs
# - it is using the automatic differentiation to easily compute the gradient of complex functions
# - it is one of the most important deep learning library
# - it can interact with classical machine learning libraries like *Scikit-learn*
#
# This lab session is an introduction. It gives you the general concepts of neural nets and helps you to implement them using a dedicated Python library. If you want to play with similar regression and classification examples in small dimensions, you can use http://playground.tensorflow.org/. For more details concerning the implementation of PyTorch, please visit this tutorial at https://pytorch.org/tutorials/.

# %%
# Import classic libraries (Matplotlib and PyLab)
# %matplotlib inline
# %pylab inline

# Import PyTorch
import torch
import torch.nn as nn
import torch.optim as optim

# Parameters (figure size and random seed)
pylab.rcParams['figure.figsize'] = (15,15)
torch.manual_seed(1)
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# **Linear regression**
#
# Simple regression is a linear problem between continuous variables $x$ and $y$. Here, we write the model $y=2+0.5x$ and generate $y$ using an additional Gaussian standard random noise.

# %%
# Generate data
x = torch.randn(1000, 1)*10 # input variable
y_true = 2 + 0.5*x # true model
y = y_true + torch.randn(1000, 1)*2 # add noise to the truth

# Plot noisy data and true model
plot(x, y_true, 'r')
plot(x, y, 'b.')
legend(['Model', 'Data'], prop={'size': 20})
title('Linear regression', size=20)
xlabel('x', size=20)
ylabel('y', size=20)
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# The objective is to build a neural net to fit the relationship between $x$ and $y$. In PyTorch, it is necessary to create a specific class for each neural network architecture. Below, we declare the neural network corresponding to a linear regression.

# %%
# Declare a class for linear regression
class linear_regression_nn(nn.Module):
    
    # class initialization
    def __init__(self, input_size, output_size):
        super(linear_regression_nn, self).__init__()
        # fully connected layer with linear activation
        self.fc = nn.Linear(input_size, output_size)
        
    # function to apply the neural network
    def forward(self, x):
        y_pred = self.fc(x)
        return y_pred

# %% [markdown]
# Then, we create a neural network based on the specific architecture declared above. We finally check the values of the parameters (randomly generated).

# %%
# Create the neural network (1 input size for x and 1 output size for y, bias is declared by default)
linear_regression_model = linear_regression_nn(1, 1)

# Print the model architecture
print(linear_regression_model)

# Print the model parameters (weights of the neural network)
slope, bias = linear_regression_model.parameters()
print('Slope: ', slope)
print('Bias: ', bias)
# Out:
# linear_regression_nn(
#   (fc): Linear(in_features=1, out_features=1, bias=True)
# )
# Slope:  Parameter containing:
# tensor([[0.0292]], requires_grad=True)
# Bias:  Parameter containing:
# tensor([-0.5334], requires_grad=True)

# %% [markdown]
# <img src="https://tandeo.files.wordpress.com/2020/09/simple_regression_dl.png">

# %% [markdown]
# In order to quantify the quality of the fit given by the neural network, we define a loss function. For a regression problem, the classic loss function is the Mean Squared Error (MSE). But other loss functions are already defined in PyTorch: https://pytorch.org/docs/stable/nn.html#loss-functions.
#
# Then, to compute the gradient of the loss function w.r.t. the parameters of the neural network, we use an optimization technique. A classic procedure is the Stochastic Gradient Descent (SQG). Other optimizers are coded in PyTorch: https://pytorch.org/docs/stable/optim.html#.

# %%
# Loss function: MSE = sum [(y - y_pred)^2], with y_pred = w0 + w1*x
criterion = nn.MSELoss()

# Optimizer: new_parameters = old_parameters - lr*gradient, with lr the learning rate
optimizer = torch.optim.SGD(linear_regression_model.parameters(), lr = 0.001)

# %% [markdown]
# Now, we fit the neural network using the ($x$, $y$) dataset. At each iteration (epoch), the loss function is stored and the estimated regression line is plotted.

# %%
epochs = 1000 # number of epochs
losses = [] # list to stock the loss at each iteration

# Loop on epochs
for i in range(epochs):
    
    # compute the prediction using the previous parameters of the neural network
    y_pred = linear_regression_model.forward(x)
    
    # compute and stock the loss
    loss = criterion(y_pred, y)
    losses.append(loss.detach().numpy())
    
    # initialize the gradient to zero
    optimizer.zero_grad()
    
    # compute the gradient by back propagation
    loss.backward()
    
    # update the parameter values using the gradient
    optimizer.step()
    
    # plot the adjustment at each epoch
    plot(x, y_true, 'r')
    plot(x, y, 'b.')
    plot(x, y_pred.detach().numpy(), 'g')
    legend(['Model', 'Data', 'Successive fits'], prop={'size': 20})
    title('Linear regression', size=20)
    xlabel('x', size=20)
    ylabel('y', size=20)

# %% [markdown]
# It is important to check that the loss function is decreasing. If not, it maybe means that the learning rate in the optimization procedure is too large.

# %%
# Print the loss function
plot(range(epochs), losses)
title('Loss function', size=20)
xlabel('Epoch', size=20)
ylabel('Loss value', size=20)
# Out:
# Text(0, 0.5, 'Loss value')

# %% [markdown]
# Finally, let's check if the estimated parameters (at the last epoch) are close to the true ones (i.e., $0.5$ for the slope and $2$ for the bias).

# %%
# Extract and print the model parameters (weights of the neural network)
slope, bias = linear_regression_model.parameters()
print('Slope: ', slope)
print('Bias: ', bias)
# Out:
# Slope:  Parameter containing:
# tensor([[0.4941]], requires_grad=True)
# Bias:  Parameter containing:
# tensor([1.5506], requires_grad=True)

# %% [markdown]
# **Nonlinear regression**
#
# Now, we perform a multiple regression between continuous variables $x$ and $y$. Here, we write the nonlinear model $y=2+0.5x-0.05x^2$ and generate $y$ using an additional Gaussian standard random noise.

# %%
# Generate data
x = torch.randn(1000, 1)*10 # input variable
y_true = 2 + 0.5*x - 0.05*x**2 # true model
y = y_true + torch.randn(1000, 1)*2 # add noise to the truth

# Plot noisy data and true model
plot(x, y_true, 'r.')
plot(x, y, 'b.')
legend(['Model', 'Data'], prop={'size': 20})
title('Nonlinear regression', size=20)
xlabel('x', size=20)
ylabel('y', size=20)
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# We declare the neural network corresponding to a nonlinear regression. The nonlinearities are introduced by a hidden layer with ReLu activations. Other activation functions are available in PyTorch: https://pytorch.org/docs/stable/nn.html#non-linear-activations-weighted-sum-nonlinearity.

# %%
# Declare a class for nonlinear regression
class nonlinear_regression_nn(nn.Module):
    
    # class initialization
    def __init__(self, input_size, hidden_size, output_size):
        super(nonlinear_regression_nn, self).__init__()
        # fully connected layer with linear activation
        self.fc0 = nn.Linear(input_size, hidden_size)
        # ReLu activation
        self.relu = nn.ReLU()
        # fully connected layer with linear activation
        self.fc1 = nn.Linear(hidden_size, output_size)
        
    # function to apply the neural network
    def forward(self, x):
        out = self.fc0(x)
        out = self.relu(out)
        y_pred = self.fc1(out)
        return y_pred
    
# Create the neural network (1 input size for x, 6 neurons in the hidden layer, and 1 output size for y)
nonlinear_regression_model = nonlinear_regression_nn(1, 6, 1)

# %% [markdown]
# We then can check the structure of the network and see the parameter vales (randomly generated).

# %%
# Print the model parameters (weights of the neural network)
for name, param in nonlinear_regression_model.named_parameters():
    if param.requires_grad:
        print(name, param.data)
# Out:
# fc0.weight tensor([[-0.7187],
#         [-0.3857],
#         [-0.2343],
#         [-0.5503],
#         [-0.1648],
#         [ 0.6943]])
# fc0.bias tensor([ 0.5165, -0.6734,  0.6508,  0.2039,  0.1187,  0.0865])
# fc1.weight tensor([[-0.2019, -0.3385,  0.0936,  0.3533, -0.3352,  0.3632]])
# fc1.bias tensor([0.2127])

# %% [markdown]
# <img src="https://tandeo.files.wordpress.com/2020/09/multiple_regression_dl.png">

# %% [markdown]
# We still use the SGD optimzer and MSE loss function.

# %%
# Loss function: MSE = sum [(y - y_pred)^2]
criterion = nn.MSELoss()

# Optimizer: new_parameters = old_parameters - lr*gradient, with lr the learning rate
optimizer = torch.optim.SGD(nonlinear_regression_model.parameters(), lr = 0.001)

# %% [markdown]
# Now, we fit the neural network using the ($x$, $y$) dataset.

# %%
epochs = 20000 # number of epochs
losses = [] # list to stock the loss at each iteration

# Loop on epochs
for i in range(epochs):
    
    # compute the prediction using the previous parameters of the neural network
    y_pred = nonlinear_regression_model.forward(x)
    
    # compute and stock the loss
    loss = criterion(y_pred, y)
    losses.append(loss.detach().numpy())
    
    # initialize the gradient to zero
    optimizer.zero_grad()
    
    # compute the gradient by back propagation
    loss.backward()
    
    # update the parameter values using the gradient
    optimizer.step()

# %% [markdown]
# The loss function is then plotted.

# %%
# Print the loss function
plot(range(epochs), losses)
title('Loss function', size=20)
xlabel('Epoch', size=20)
ylabel('Loss value', size=20)
# Out:
# Text(0, 0.5, 'Loss value')

# %% [markdown]
# Finally, the estimated model (last iteration of the neural network) is plotted.

# %%
# plot the adjustment at the last epoch
plot(x, y_true, 'r.')
plot(x, y, 'b.')
plot(x, y_pred.detach().numpy(), 'g.')
legend(['Model', 'Data', 'Fit'], prop={'size': 20})
title('Nonlinear regression', size=20)
xlabel('x', size=20)
ylabel('y', size=20)
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# **Logistic regression (binary classification)**
#
# In a classification problem, $y$ is a discrete variable with various classes. Here, $y$ is binary and takes its values between $0$ and $1$. We write the model as $y=f\left(2+0.5 x\right)$ with $f$ the logistic transfer function (sigmoid). As previously, we generate $y$ adding Gaussian perturbations.

# %%
# Generate data
x = torch.randn(1000, 1)*10 # input variable
y_true = 1 / (1 + exp(-(2 + 0.5*x))) # true model
y_noise = 1 / (1 + exp(-(2 + 0.5*x + torch.randn(1000, 1)*2))) # add noise to the truth
y = (y_noise>0.5).float() # transform to binary data

# Plot noisy data and true model
plot(x, y_true, 'r.')
plot(x, y, 'b.')
legend(['Model', 'Data'], prop={'size': 20})
title('Logistic regression', size=20)
xlabel('x', size=20)
ylabel('y', size=20)
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# Define your own neural network to fit the data generated below. Be careful, the logistic regression is a classification problem. The output $y$ is binary. You thus have to use appropriate activation and loss functions.

# %% [markdown]
# <img src="https://tandeo.files.wordpress.com/2020/09/logistic_regression_dl.png">

# %%
# Declare a class for logistic regression
class logistic_regression_nn(nn.Module):
    
   # class initialization
    def __init__(self, input_size, output_size):
        super(logistic_regression_nn, self).__init__()
        # fully connected layer with linear activation
        self.fc = nn.Linear(input_size, output_size)
        self.sigmoid = nn.Sigmoid()
        
    # function to apply the neural network
    def forward(self, x):
        y_pred = self.fc(x)
        y_pred = self.sigmoid(y_pred)
        return y_pred
    
# Create the neural network (1 input size for x, and 1 output size for y)
logistic_regression_model = logistic_regression_nn(1, 1)

# %%
# Loss function: MSE = sum [(y - y_pred)^2], with y_pred = w0 + w1*x
criterion = nn.BCELoss()

# Optimizer: new_parameters = old_parameters - lr*gradient, with lr the learning rate
optimizer = torch.optim.SGD(logistic_regression_model.parameters(), lr = 0.001)

# %%
epochs = 20000 # number of epochs
losses = [] # list to stock the loss at each iteration

# Loop on epochs
for i in range(epochs):
    
    # compute the prediction using the previous parameters of the neural network
    y_pred = logistic_regression_model.forward(x)
    
    # compute and stock the loss
    loss = criterion(y_pred, y)
    losses.append(loss.detach().numpy())
    
    # initialize the gradient to zero
    optimizer.zero_grad()
    
    # compute the gradient by back propagation
    loss.backward()
    
    # update the parameter values using the gradient
    optimizer.step()

# %%
# plot the adjustment at the last epoch
plot(x, y_true, 'r.')
plot(x, y, 'b.')
plot(x, y_pred.detach().numpy(), 'g.')
legend(['Model', 'Data', 'Fit'], prop={'size': 20})
title('Nonlinear regression', size=20)
xlabel('x', size=20)
ylabel('y', size=20)
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# **Automatic differentiation of the sigmoid function**
#
# A neural network is based on the minimization of a cost function (also called loss function) w.r.t. to some parameters, these parameters corresponding to the weights of the network. The loss function measures the adequacy between the observed data and the model (i.e., the neural network).
#
# In deep learning architectures, a loss function is corresponding to a succession of several activation functions (e.g., linear, ReLU, sigmoid). The minimization of the loss function is performed using gradient descent algorithms, and computation of the gradients is performed using automatic differentiation.

# %% [markdown]
# Below, we define a sigmoid function, well known in neural networks, especially for classification problems. The analytic derivative of the sigmoid function is also defined.

# %%
# Define the sigmoid function
def f(x):
    return (torch.sigmoid(x))

# Define the first derivative of the sigmoid function
def f_prime(x):
    return (torch.exp(-x) / (1 + torch.exp(-x))**2)

# %% [markdown]
# Then, we compare the analytic solution to the approximation computed by automatic differentiation in PyTorch.

# %%
# Generate data
x = torch.linspace(-5.0, 5.0, 100, requires_grad=True)
f_x = f(x)
f_prime_x = f_prime(x)

# Apply the automatic differentiation
y = torch.sum(f(x))
y.backward(retain_graph=True)
x.grad

# Plot results
subplot(2,1,1)
plot(x.detach().numpy(), f_x.detach().numpy(), 'b')
plot(x.detach().numpy(), f_prime_x.detach().numpy(), 'g')
plot(x.detach().numpy(), x.grad.detach().numpy(), 'r--', linewidth=5)
legend(['f(x) = sigmoid(x)', 'f prime (analytic)', 'f prime (automatic)'], prop={'size': 20})
title('Sigmoid function and its first derivative', size=20)
xlabel('x', size=20)
# Out:
# Text(0.5, 0, 'x')

# %% [markdown]
# The analytic derivative and the one estimated by automatic differentiation are similar.

# %% [markdown]
# **Optimization of a 2D function using automatic differentiation**
#
# Now, let's take an example of classification with several inputs $x_1, x_2, x_1^2, x_2^2, x_1 x_2$ (resulting in nonlinearities) and a binary output $y$ (i.e., $y=0$ or $y=1$). We define a model $f$ with 6 parameters $w$, including the bias, such that $f(x_1, x_2, w) = sigmoid{(w_0 + w_1 x_1 + w_2 x_2 + w_{11} x_1^2 + w_{22} x_2^2 + w_{12} x_1 x_2)}$. The binary output $y$ is defined as the following: if $f(x_1, x_2, w)\leq0.5$ then $y=0$, and if $f(x_1, x_2, w)>0.5$ then $y=1$.
#
# The goal here is to: (i) generate $x_1$, $x_2$, and $y$ data, (ii) estimate the $w$ parameters using a classic gradient-descent optimization procedure based on automatic differentiation, (iii) compare the estimated parameters with the true ones.

# %%
# Fix the seed
torch.manual_seed(1)

# Input variables
x1 = torch.randn(100, 1)
x2 = torch.randn(100, 1)

# True parameters
w0 = -0.5
w1 = 1.5
w2 = 0.5
w11 = 0.75
w22 = 0.25
w12 = 0.5

# Noise
epsilon = torch.randn(100, 1)/3

# Output variable
y_noise = torch.sigmoid(w0 + w1*x1 + w2*x2 + w11*x1**2 + w22*x2**2 + w12*x1*x2 + epsilon)
y = (y_noise>0.5).float() # transform to binary data
# For visualization
X1, X2 = torch.meshgrid(torch.linspace(-4, 4, 100), torch.linspace(-4, 4, 100))
Y = torch.sigmoid(w0 + w1*X1 + w2*X2 + w11*X1**2 + w22*X2**2 + w12*X1*X2)

# Plot data
scatter(x1[y==0], x2[y==0], c='b')
scatter(x1[y==1], x2[y==1], c='r')
contourf(X1, X2, Y, cmap='bwr', alpha=0.5)
scatter(x1, x2, c=y, cmap='bwr')
xlabel("$x_1$", fontsize=20)
ylabel("$x_2$", fontsize=20)
title('Nonlinear classification', size=20)
legend(['y = 0', 'y = 1'], prop={'size': 20})
# Out:
# c:\Users\kaddy\anaconda3\envs\Deeplearning\Lib\site-packages\torch\functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\b\abs_abjetg6_iu\croot\pytorch_1686932924616\work\aten\src\ATen\native\TensorShape.cpp:3484.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %% [markdown]
# Firstly, define the loss function for such a binary classification. A classic one is the BCE defined as $\sum_{i=1}^n \left[ - y_i \log(\hat{y}_i) - (1 - y_i) \log(1 - \hat{y}_i) \right]$, with $\hat{y}$ the prediction of the model $f(x_1, x_2, w)$, defined by the 6 parameters $w$ and the input variables $x_1, \dots, x_1 x_2$.

# %%
# defining the prediction model function
def prediction_model(x1, x2, w):
    # Noise
    epsilon = torch.randn(100, 1)/3

    # Output variable
    y= torch.sigmoid(w[0] + w[1]*x1 + w[2]*x2 + w[3]*x1**2 + w[4]*x2**2 + w[5]*x1*x2 + epsilon)
    return y

# %%
# defining the loss 
def loss_function(x1, x2, y, w):
    y_pred = prediction_model(x1, x2, w)
    criterion = nn.BCELoss()
    loss = criterion(y_pred, y)
    return loss

# %% [markdown]
# Secondly, we use the *autograd* module of PyTorch to compute automatically the gradient of the loss function defined before. As an example, we evaluate for instance the gradient when $w$ parameters are randomly sampled using a Gaussian distribution with mean $0$ and variance $1/n$, with $n$ the number of parameters. The parameter $w_0$, corresponding to the bias, is initialize with zero. More details about the initialization of a neural network are discussed here: https://www.deeplearning.ai/ai-notes/initialization/).

# %%
from torch.autograd import Variable

# Define initial parameter values
w = Variable(torch.cat((torch.zeros(1), torch.randn(5)*sqrt(1/6))), requires_grad = True)
# compute the loss
loss = torch.sum(loss_function(X1,X2, Y, w))

# Apply backpropagation
loss.backward(retain_graph=True)

# Compute the gradient of the loss function evaluated at w
gradient = w.grad

# Print results
print('Loss: ', loss)
print('Gradient: ', gradient)
# Out:
# tensor(0.6444, grad_fn=<SumBackward0>)
# Loss:  tensor(0.6444, grad_fn=<SumBackward0>)
# Gradient:  tensor([ 0.0751, -0.0469,  0.0039,  0.0280,  0.5352, -0.3072])

# %% [markdown]
# Thirdly, implement your own gradient descent algorithm to iteratively update the parameters $w$ of your model. To generate the initial condition of your algorithm (i.e., the initial set of parameters $w$), use the same random procedure as below. Use a classic learning rate of $10^{-4}$.
#
#
# Plot the results of your classification model. Also check the estimated parameter values, they may be different from the real ones.

# %%
# defining backpropagation algorithm
def back_propagation(w):
    # compute the loss
    loss = torch.sum(loss_function(X1,X2, Y, w))

    # Apply backpropagation
    loss.backward(retain_graph=True)

    # Compute the gradient of the loss function evaluated at w
    gradient = w.grad

    new_w = torch.tensor(w - 10**(-4) * gradient, requires_grad = True)
    print(loss)

    return new_w

current_w = Variable(torch.cat((torch.zeros(1), torch.randn(5)*sqrt(1/6))), requires_grad = True)
new_w = back_propagation(current_w)
n= 1
while not torch.equal(current_w , new_w) and n<10000:
    current_w= new_w
    new_w = back_propagation(current_w)
    n=n+1
print(new_w)
# Out:
# C:\Users\kaddy\AppData\Local\Temp\ipykernel_3452\4089364488.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   new_w = torch.tensor(w - 10**(-4) * gradient, requires_grad = True)
# tensor(2.1593, grad_fn=<SumBackward0>)
# tensor(2.1644, grad_fn=<SumBackward0>)
# tensor(2.1432, grad_fn=<SumBackward0>)
# tensor(2.1458, grad_fn=<SumBackward0>)
# tensor(2.1451, grad_fn=<SumBackward0>)
# tensor(2.1536, grad_fn=<SumBackward0>)
# tensor(2.1568, grad_fn=<SumBackward0>)
# tensor(2.1417, grad_fn=<SumBackward0>)
# tensor(2.1371, grad_fn=<SumBackward0>)
# tensor(2.1161, grad_fn=<SumBackward0>)
# tensor(2.1399, grad_fn=<SumBackward0>)
# tensor(2.1322, grad_fn=<SumBackward0>)
# tensor(2.1349, grad_fn=<SumBackward0>)
# tensor(2.1320, grad_fn=<SumBackward0>)
# tensor(2.1291, grad_fn=<SumBackward0>)
# tensor(2.1323, grad_fn=<SumBackward0>)
# tensor(2.1240, grad_fn=<SumBackward0>)
# tensor(2.1562, grad_fn=<SumBackward0>)
# tensor(2.1425, grad_fn=<SumBackward0>)
# tensor(2.1188, grad_fn=<SumBackward0>)
# tensor(2.1462, grad_fn=<SumBackward0>)
# tensor(2.1239, grad_fn=<SumBackward0>)
# tensor(2.1285, grad_fn=<SumBackward0>)
# tensor(2.1386, grad_fn=<SumBackward0>)
# tensor(2.1163, grad_fn=<SumBackward0>)
# tensor(2.1455, grad_fn=<SumBackward0>)
# tensor(2.1233, grad_fn=<SumBackward0>)
# tensor(2.1145, grad_fn=<SumBackward0>)
# tensor(2.1150, grad_fn=<SumBackward0>)
# tensor(2.1094, grad_fn=<SumBackward0>)
# tensor(2.1026, grad_fn=<SumBackward0>)
# tensor(2.1136, grad_fn=<SumBackward0>)
# tensor(2.1111, grad_fn=<SumBackward0>)
# tensor(2.1118, grad_fn=<SumBackward0>)
# tensor(2.1118, grad_fn=<SumBackward0>)
# tensor(2.0985, grad_fn=<SumBackward0>)
# tensor(2.0990, grad_fn=<SumBackward0>)
# tensor(2.1057, grad_fn=<SumBackward0>)
# tensor(2.1128, grad_fn=<SumBackward0>)
# tensor(2.0982, grad_fn=<SumBackward0>)
# tensor(2.0924, grad_fn=<SumBackward0>)
# tensor(2.1217, grad_fn=<SumBackward0>)
# tensor(2.1077, grad_fn=<SumBackward0>)
# tensor(2.0947, grad_fn=<SumBackward0>)
# tensor(2.0815, grad_fn=<SumBackward0>)
# tensor(2.1070, grad_fn=<SumBackward0>)
# tensor(2.0804, grad_fn=<SumBackward0>)
# tensor(2.0827, grad_fn=<SumBackward0>)
# tensor(2.1064, grad_fn=<SumBackward0>)
# tensor(2.0728, grad_fn=<SumBackward0>)
# tensor(2.0836, grad_fn=<SumBackward0>)
# tensor(2.0854, grad_fn=<SumBackward0>)
# tensor(2.0906, grad_fn=<SumBackward0>)
# tensor(2.0721, grad_fn=<SumBackward0>)
# tensor(2.0742, grad_fn=<SumBackward0>)
# tensor(2.0887, grad_fn=<SumBackward0>)
# tensor(2.0695, grad_fn=<SumBackward0>)
# tensor(2.0691, grad_fn=<SumBackward0>)
# tensor(2.0661, grad_fn=<SumBackward0>)
# tensor(2.0666, grad_fn=<SumBackward0>)
# tensor(2.0615, grad_fn=<SumBackward0>)
# tensor(2.0601, grad_fn=<SumBackward0>)
# tensor(2.0483, grad_fn=<SumBackward0>)
# tensor(2.0619, grad_fn=<SumBackward0>)
# tensor(2.0932, grad_fn=<SumBackward0>)
# tensor(2.0521, grad_fn=<SumBackward0>)
# tensor(2.0485, grad_fn=<SumBackward0>)
# tensor(2.0780, grad_fn=<SumBackward0>)
# tensor(2.0509, grad_fn=<SumBackward0>)
# tensor(2.0427, grad_fn=<SumBackward0>)
# tensor(2.0692, grad_fn=<SumBackward0>)
# tensor(2.0601, grad_fn=<SumBackward0>)
# tensor(2.0596, grad_fn=<SumBackward0>)
# tensor(2.0486, grad_fn=<SumBackward0>)
# tensor(2.0599, grad_fn=<SumBackward0>)
# tensor(2.0611, grad_fn=<SumBackward0>)
# tensor(2.0435, grad_fn=<SumBackward0>)
# tensor(2.0334, grad_fn=<SumBackward0>)
# tensor(2.0594, grad_fn=<SumBackward0>)
# tensor(2.0363, grad_fn=<SumBackward0>)
# tensor(2.0290, grad_fn=<SumBackward0>)
# tensor(2.0417, grad_fn=<SumBackward0>)
# tensor(2.0369, grad_fn=<SumBackward0>)
# tensor(2.0336, grad_fn=<SumBackward0>)
# tensor(2.0179, grad_fn=<SumBackward0>)
# tensor(2.0369, grad_fn=<SumBackward0>)
# tensor(2.0304, grad_fn=<SumBackward0>)
# tensor(2.0875, grad_fn=<SumBackward0>)
# tensor(2.0219, grad_fn=<SumBackward0>)
# tensor(2.0252, grad_fn=<SumBackward0>)
# tensor(2.0300, grad_fn=<SumBackward0>)
# tensor(2.0078, grad_fn=<SumBackward0>)
# tensor(2.0307, grad_fn=<SumBackward0>)
# tensor(2.0005, grad_fn=<SumBackward0>)
# tensor(2.0077, grad_fn=<SumBackward0>)
# tensor(2.0066, grad_fn=<SumBackward0>)
# tensor(2.0174, grad_fn=<SumBackward0>)
# tensor(2.0426, grad_fn=<SumBackward0>)
# tensor(2.0216, grad_fn=<SumBackward0>)
# tensor(1.9947, grad_fn=<SumBackward0>)
# tensor(1.9978, grad_fn=<SumBackward0>)
# tensor(2.0011, grad_fn=<SumBackward0>)
# tensor(2.0126, grad_fn=<SumBackward0>)
# tensor(2.0050, grad_fn=<SumBackward0>)
# tensor(1.9978, grad_fn=<SumBackward0>)
# tensor(1.9902, grad_fn=<SumBackward0>)
# tensor(1.9996, grad_fn=<SumBackward0>)
# tensor(2.0161, grad_fn=<SumBackward0>)
# tensor(2.0004, grad_fn=<SumBackward0>)
# tensor(2.0170, grad_fn=<SumBackward0>)
# tensor(2.0094, grad_fn=<SumBackward0>)
# tensor(2.0017, grad_fn=<SumBackward0>)
# tensor(2.0095, grad_fn=<SumBackward0>)
# tensor(1.9903, grad_fn=<SumBackward0>)
# tensor(1.9952, grad_fn=<SumBackward0>)
# tensor(1.9605, grad_fn=<SumBackward0>)
# tensor(1.9886, grad_fn=<SumBackward0>)
# tensor(1.9850, grad_fn=<SumBackward0>)
# tensor(2.0030, grad_fn=<SumBackward0>)
# tensor(1.9764, grad_fn=<SumBackward0>)
# tensor(1.9912, grad_fn=<SumBackward0>)
# tensor(2.0013, grad_fn=<SumBackward0>)
# tensor(1.9978, grad_fn=<SumBackward0>)
# tensor(1.9726, grad_fn=<SumBackward0>)
# tensor(1.9894, grad_fn=<SumBackward0>)
# tensor(1.9844, grad_fn=<SumBackward0>)
# tensor(1.9604, grad_fn=<SumBackward0>)
# tensor(1.9745, grad_fn=<SumBackward0>)
# tensor(1.9698, grad_fn=<SumBackward0>)
# tensor(1.9680, grad_fn=<SumBackward0>)
# tensor(1.9936, grad_fn=<SumBackward0>)
# tensor(1.9771, grad_fn=<SumBackward0>)
# tensor(1.9837, grad_fn=<SumBackward0>)
# tensor(1.9651, grad_fn=<SumBackward0>)
# tensor(2.0056, grad_fn=<SumBackward0>)
# tensor(1.9625, grad_fn=<SumBackward0>)
# tensor(1.9364, grad_fn=<SumBackward0>)
# tensor(1.9482, grad_fn=<SumBackward0>)
# tensor(1.9553, grad_fn=<SumBackward0>)
# tensor(1.9505, grad_fn=<SumBackward0>)
# tensor(1.9619, grad_fn=<SumBackward0>)
# tensor(1.9680, grad_fn=<SumBackward0>)
# tensor(1.9464, grad_fn=<SumBackward0>)
# tensor(1.9625, grad_fn=<SumBackward0>)
# tensor(1.9623, grad_fn=<SumBackward0>)
# tensor(1.9209, grad_fn=<SumBackward0>)
# tensor(1.9737, grad_fn=<SumBackward0>)
# tensor(1.9589, grad_fn=<SumBackward0>)
# tensor(1.9421, grad_fn=<SumBackward0>)
# tensor(1.9469, grad_fn=<SumBackward0>)
# tensor(1.9535, grad_fn=<SumBackward0>)
# tensor(1.9596, grad_fn=<SumBackward0>)
# tensor(1.9399, grad_fn=<SumBackward0>)
# tensor(1.9358, grad_fn=<SumBackward0>)
# tensor(1.9193, grad_fn=<SumBackward0>)
# tensor(1.9311, grad_fn=<SumBackward0>)
# tensor(1.9410, grad_fn=<SumBackward0>)
# tensor(1.9159, grad_fn=<SumBackward0>)
# tensor(1.9388, grad_fn=<SumBackward0>)
# tensor(1.9215, grad_fn=<SumBackward0>)
# tensor(1.9312, grad_fn=<SumBackward0>)
# tensor(1.9489, grad_fn=<SumBackward0>)
# tensor(1.9121, grad_fn=<SumBackward0>)
# tensor(1.9080, grad_fn=<SumBackward0>)
# tensor(1.9258, grad_fn=<SumBackward0>)
# tensor(1.9103, grad_fn=<SumBackward0>)
# tensor(1.9386, grad_fn=<SumBackward0>)
# tensor(1.9325, grad_fn=<SumBackward0>)
# tensor(1.9148, grad_fn=<SumBackward0>)
# tensor(1.9056, grad_fn=<SumBackward0>)
# tensor(1.9199, grad_fn=<SumBackward0>)
# tensor(1.9053, grad_fn=<SumBackward0>)
# tensor(1.9126, grad_fn=<SumBackward0>)
# tensor(1.9201, grad_fn=<SumBackward0>)
# tensor(1.9255, grad_fn=<SumBackward0>)
# tensor(1.8996, grad_fn=<SumBackward0>)
# tensor(1.9033, grad_fn=<SumBackward0>)
# tensor(1.8972, grad_fn=<SumBackward0>)
# tensor(1.9058, grad_fn=<SumBackward0>)
# tensor(1.9111, grad_fn=<SumBackward0>)
# tensor(1.9031, grad_fn=<SumBackward0>)
# tensor(1.8907, grad_fn=<SumBackward0>)
# tensor(1.9119, grad_fn=<SumBackward0>)
# tensor(1.9060, grad_fn=<SumBackward0>)
# tensor(1.9201, grad_fn=<SumBackward0>)
# tensor(1.8881, grad_fn=<SumBackward0>)
# tensor(1.8798, grad_fn=<SumBackward0>)
# tensor(1.9104, grad_fn=<SumBackward0>)
# tensor(1.9087, grad_fn=<SumBackward0>)
# tensor(1.8898, grad_fn=<SumBackward0>)
# tensor(1.8787, grad_fn=<SumBackward0>)
# tensor(1.8856, grad_fn=<SumBackward0>)
# tensor(1.8668, grad_fn=<SumBackward0>)
# tensor(1.8766, grad_fn=<SumBackward0>)
# tensor(1.8973, grad_fn=<SumBackward0>)
# tensor(1.8988, grad_fn=<SumBackward0>)
# tensor(1.8964, grad_fn=<SumBackward0>)
# tensor(1.8801, grad_fn=<SumBackward0>)
# tensor(1.8991, grad_fn=<SumBackward0>)
# tensor(1.8634, grad_fn=<SumBackward0>)
# tensor(1.8662, grad_fn=<SumBackward0>)
# tensor(1.8813, grad_fn=<SumBackward0>)
# tensor(1.8734, grad_fn=<SumBackward0>)
# tensor(1.8746, grad_fn=<SumBackward0>)
# tensor(1.8874, grad_fn=<SumBackward0>)
# tensor(1.8880, grad_fn=<SumBackward0>)
# tensor(1.8761, grad_fn=<SumBackward0>)
# tensor(1.8605, grad_fn=<SumBackward0>)
# tensor(1.8580, grad_fn=<SumBackward0>)
# tensor(1.8473, grad_fn=<SumBackward0>)
# tensor(1.8627, grad_fn=<SumBackward0>)
# tensor(1.8720, grad_fn=<SumBackward0>)
# tensor(1.8709, grad_fn=<SumBackward0>)
# tensor(1.8660, grad_fn=<SumBackward0>)
# tensor(1.8677, grad_fn=<SumBackward0>)
# tensor(1.8561, grad_fn=<SumBackward0>)
# tensor(1.8426, grad_fn=<SumBackward0>)
# tensor(1.8457, grad_fn=<SumBackward0>)
# tensor(1.8609, grad_fn=<SumBackward0>)
# tensor(1.8253, grad_fn=<SumBackward0>)
# tensor(1.8510, grad_fn=<SumBackward0>)
# tensor(1.8812, grad_fn=<SumBackward0>)
# tensor(1.8511, grad_fn=<SumBackward0>)
# tensor(1.8713, grad_fn=<SumBackward0>)
# tensor(1.8496, grad_fn=<SumBackward0>)
# tensor(1.8372, grad_fn=<SumBackward0>)
# tensor(1.8301, grad_fn=<SumBackward0>)
# tensor(1.8395, grad_fn=<SumBackward0>)
# tensor(1.8435, grad_fn=<SumBackward0>)
# tensor(1.8445, grad_fn=<SumBackward0>)
# tensor(1.8289, grad_fn=<SumBackward0>)
# tensor(1.8433, grad_fn=<SumBackward0>)
# tensor(1.8382, grad_fn=<SumBackward0>)
# tensor(1.8343, grad_fn=<SumBackward0>)
# tensor(1.8343, grad_fn=<SumBackward0>)
# tensor(1.8486, grad_fn=<SumBackward0>)
# tensor(1.8026, grad_fn=<SumBackward0>)
# tensor(1.8173, grad_fn=<SumBackward0>)
# tensor(1.8442, grad_fn=<SumBackward0>)
# tensor(1.8267, grad_fn=<SumBackward0>)
# tensor(1.8091, grad_fn=<SumBackward0>)
# tensor(1.8408, grad_fn=<SumBackward0>)
# tensor(1.8356, grad_fn=<SumBackward0>)
# tensor(1.8146, grad_fn=<SumBackward0>)
# tensor(1.8204, grad_fn=<SumBackward0>)
# tensor(1.8349, grad_fn=<SumBackward0>)
# tensor(1.8450, grad_fn=<SumBackward0>)
# tensor(1.8211, grad_fn=<SumBackward0>)
# tensor(1.8117, grad_fn=<SumBackward0>)
# tensor(1.8048, grad_fn=<SumBackward0>)
# tensor(1.8057, grad_fn=<SumBackward0>)
# tensor(1.8149, grad_fn=<SumBackward0>)
# tensor(1.8033, grad_fn=<SumBackward0>)
# tensor(1.7957, grad_fn=<SumBackward0>)
# tensor(1.8134, grad_fn=<SumBackward0>)
# tensor(1.8047, grad_fn=<SumBackward0>)
# tensor(1.8100, grad_fn=<SumBackward0>)
# tensor(1.8184, grad_fn=<SumBackward0>)
# tensor(1.7952, grad_fn=<SumBackward0>)
# tensor(1.7887, grad_fn=<SumBackward0>)
# tensor(1.7938, grad_fn=<SumBackward0>)
# tensor(1.8117, grad_fn=<SumBackward0>)
# tensor(1.8065, grad_fn=<SumBackward0>)
# tensor(1.7804, grad_fn=<SumBackward0>)
# tensor(1.8006, grad_fn=<SumBackward0>)
# tensor(1.8006, grad_fn=<SumBackward0>)
# tensor(1.7932, grad_fn=<SumBackward0>)
# tensor(1.7865, grad_fn=<SumBackward0>)
# tensor(1.8109, grad_fn=<SumBackward0>)
# tensor(1.8087, grad_fn=<SumBackward0>)
# tensor(1.7945, grad_fn=<SumBackward0>)
# tensor(1.7953, grad_fn=<SumBackward0>)
# tensor(1.7920, grad_fn=<SumBackward0>)
# tensor(1.7775, grad_fn=<SumBackward0>)
# tensor(1.8081, grad_fn=<SumBackward0>)
# tensor(1.7833, grad_fn=<SumBackward0>)
# tensor(1.7786, grad_fn=<SumBackward0>)
# tensor(1.7779, grad_fn=<SumBackward0>)
# tensor(1.7789, grad_fn=<SumBackward0>)
# tensor(1.7847, grad_fn=<SumBackward0>)
# tensor(1.7683, grad_fn=<SumBackward0>)
# tensor(1.7746, grad_fn=<SumBackward0>)
# tensor(1.7671, grad_fn=<SumBackward0>)
# tensor(1.7764, grad_fn=<SumBackward0>)
# tensor(1.7760, grad_fn=<SumBackward0>)
# tensor(1.7780, grad_fn=<SumBackward0>)
# tensor(1.7697, grad_fn=<SumBackward0>)
# tensor(1.7668, grad_fn=<SumBackward0>)
# tensor(1.7724, grad_fn=<SumBackward0>)
# tensor(1.7677, grad_fn=<SumBackward0>)
# tensor(1.7802, grad_fn=<SumBackward0>)
# tensor(1.7547, grad_fn=<SumBackward0>)
# tensor(1.7696, grad_fn=<SumBackward0>)
# tensor(1.7638, grad_fn=<SumBackward0>)
# tensor(1.7524, grad_fn=<SumBackward0>)
# tensor(1.7621, grad_fn=<SumBackward0>)
# tensor(1.7666, grad_fn=<SumBackward0>)
# tensor(1.7700, grad_fn=<SumBackward0>)
# tensor(1.7582, grad_fn=<SumBackward0>)
# tensor(1.7475, grad_fn=<SumBackward0>)
# tensor(1.7581, grad_fn=<SumBackward0>)
# tensor(1.7477, grad_fn=<SumBackward0>)
# tensor(1.7553, grad_fn=<SumBackward0>)
# tensor(1.7467, grad_fn=<SumBackward0>)
# tensor(1.7574, grad_fn=<SumBackward0>)
# tensor(1.7575, grad_fn=<SumBackward0>)
# tensor(1.7406, grad_fn=<SumBackward0>)
# tensor(1.7631, grad_fn=<SumBackward0>)
# tensor(1.7355, grad_fn=<SumBackward0>)
# tensor(1.7543, grad_fn=<SumBackward0>)
# tensor(1.7157, grad_fn=<SumBackward0>)
# tensor(1.7335, grad_fn=<SumBackward0>)
# tensor(1.7286, grad_fn=<SumBackward0>)
# tensor(1.7209, grad_fn=<SumBackward0>)
# tensor(1.7139, grad_fn=<SumBackward0>)
# tensor(1.7400, grad_fn=<SumBackward0>)
# tensor(1.7476, grad_fn=<SumBackward0>)
# tensor(1.7406, grad_fn=<SumBackward0>)
# tensor(1.7459, grad_fn=<SumBackward0>)
# tensor(1.7456, grad_fn=<SumBackward0>)
# tensor(1.7259, grad_fn=<SumBackward0>)
# tensor(1.7264, grad_fn=<SumBackward0>)
# tensor(1.7040, grad_fn=<SumBackward0>)
# tensor(1.7238, grad_fn=<SumBackward0>)
# tensor(1.7355, grad_fn=<SumBackward0>)
# tensor(1.7193, grad_fn=<SumBackward0>)
# tensor(1.7221, grad_fn=<SumBackward0>)
# tensor(1.7075, grad_fn=<SumBackward0>)
# tensor(1.7264, grad_fn=<SumBackward0>)
# tensor(1.7193, grad_fn=<SumBackward0>)
# tensor(1.7234, grad_fn=<SumBackward0>)
# tensor(1.7196, grad_fn=<SumBackward0>)
# tensor(1.7082, grad_fn=<SumBackward0>)
# tensor(1.7146, grad_fn=<SumBackward0>)
# tensor(1.7111, grad_fn=<SumBackward0>)
# tensor(1.7144, grad_fn=<SumBackward0>)
# tensor(1.7156, grad_fn=<SumBackward0>)
# tensor(1.6802, grad_fn=<SumBackward0>)
# tensor(1.7245, grad_fn=<SumBackward0>)
# tensor(1.6983, grad_fn=<SumBackward0>)
# tensor(1.6936, grad_fn=<SumBackward0>)
# tensor(1.6877, grad_fn=<SumBackward0>)
# tensor(1.6851, grad_fn=<SumBackward0>)
# tensor(1.6920, grad_fn=<SumBackward0>)
# tensor(1.6855, grad_fn=<SumBackward0>)
# tensor(1.7087, grad_fn=<SumBackward0>)
# tensor(1.6998, grad_fn=<SumBackward0>)
# tensor(1.6755, grad_fn=<SumBackward0>)
# tensor(1.6804, grad_fn=<SumBackward0>)
# tensor(1.6844, grad_fn=<SumBackward0>)
# tensor(1.6820, grad_fn=<SumBackward0>)
# tensor(1.6961, grad_fn=<SumBackward0>)
# tensor(1.6873, grad_fn=<SumBackward0>)
# tensor(1.6946, grad_fn=<SumBackward0>)
# tensor(1.6869, grad_fn=<SumBackward0>)
# tensor(1.7127, grad_fn=<SumBackward0>)
# tensor(1.6743, grad_fn=<SumBackward0>)
# tensor(1.6934, grad_fn=<SumBackward0>)
# tensor(1.6810, grad_fn=<SumBackward0>)
# tensor(1.7008, grad_fn=<SumBackward0>)
# tensor(1.6987, grad_fn=<SumBackward0>)
# tensor(1.6682, grad_fn=<SumBackward0>)
# tensor(1.6822, grad_fn=<SumBackward0>)
# tensor(1.6824, grad_fn=<SumBackward0>)
# tensor(1.6749, grad_fn=<SumBackward0>)
# tensor(1.6667, grad_fn=<SumBackward0>)
# tensor(1.6745, grad_fn=<SumBackward0>)
# tensor(1.6607, grad_fn=<SumBackward0>)
# tensor(1.6599, grad_fn=<SumBackward0>)
# tensor(1.6770, grad_fn=<SumBackward0>)
# tensor(1.6422, grad_fn=<SumBackward0>)
# tensor(1.6738, grad_fn=<SumBackward0>)
# tensor(1.6771, grad_fn=<SumBackward0>)
# tensor(1.6673, grad_fn=<SumBackward0>)
# tensor(1.6735, grad_fn=<SumBackward0>)
# tensor(1.6661, grad_fn=<SumBackward0>)
# tensor(1.6748, grad_fn=<SumBackward0>)
# tensor(1.6729, grad_fn=<SumBackward0>)
# tensor(1.6594, grad_fn=<SumBackward0>)
# tensor(1.6769, grad_fn=<SumBackward0>)
# tensor(1.6552, grad_fn=<SumBackward0>)
# tensor(1.6519, grad_fn=<SumBackward0>)
# tensor(1.6666, grad_fn=<SumBackward0>)
# tensor(1.6354, grad_fn=<SumBackward0>)
# tensor(1.6661, grad_fn=<SumBackward0>)
# tensor(1.6581, grad_fn=<SumBackward0>)
# tensor(1.6550, grad_fn=<SumBackward0>)
# tensor(1.6547, grad_fn=<SumBackward0>)
# tensor(1.6286, grad_fn=<SumBackward0>)
# tensor(1.6436, grad_fn=<SumBackward0>)
# tensor(1.6471, grad_fn=<SumBackward0>)
# tensor(1.6321, grad_fn=<SumBackward0>)
# tensor(1.6425, grad_fn=<SumBackward0>)
# tensor(1.6271, grad_fn=<SumBackward0>)
# tensor(1.6342, grad_fn=<SumBackward0>)
# tensor(1.6369, grad_fn=<SumBackward0>)
# tensor(1.6640, grad_fn=<SumBackward0>)
# tensor(1.6347, grad_fn=<SumBackward0>)
# tensor(1.6157, grad_fn=<SumBackward0>)
# tensor(1.6463, grad_fn=<SumBackward0>)
# tensor(1.6219, grad_fn=<SumBackward0>)
# tensor(1.6394, grad_fn=<SumBackward0>)
# tensor(1.6326, grad_fn=<SumBackward0>)
# tensor(1.6381, grad_fn=<SumBackward0>)
# tensor(1.6278, grad_fn=<SumBackward0>)
# tensor(1.6220, grad_fn=<SumBackward0>)
# tensor(1.6239, grad_fn=<SumBackward0>)
# tensor(1.6313, grad_fn=<SumBackward0>)
# tensor(1.6288, grad_fn=<SumBackward0>)
# tensor(1.6225, grad_fn=<SumBackward0>)
# tensor(1.6168, grad_fn=<SumBackward0>)
# tensor(1.5921, grad_fn=<SumBackward0>)
# tensor(1.6191, grad_fn=<SumBackward0>)
# tensor(1.6156, grad_fn=<SumBackward0>)
# tensor(1.6240, grad_fn=<SumBackward0>)
# tensor(1.6130, grad_fn=<SumBackward0>)
# tensor(1.6105, grad_fn=<SumBackward0>)
# tensor(1.6145, grad_fn=<SumBackward0>)
# tensor(1.6042, grad_fn=<SumBackward0>)
# tensor(1.6226, grad_fn=<SumBackward0>)
# tensor(1.6007, grad_fn=<SumBackward0>)
# tensor(1.5930, grad_fn=<SumBackward0>)
# tensor(1.6094, grad_fn=<SumBackward0>)
# tensor(1.6183, grad_fn=<SumBackward0>)
# tensor(1.6097, grad_fn=<SumBackward0>)
# tensor(1.6102, grad_fn=<SumBackward0>)
# tensor(1.5967, grad_fn=<SumBackward0>)
# tensor(1.5975, grad_fn=<SumBackward0>)
# tensor(1.5944, grad_fn=<SumBackward0>)
# tensor(1.5967, grad_fn=<SumBackward0>)
# tensor(1.5897, grad_fn=<SumBackward0>)
# tensor(1.5839, grad_fn=<SumBackward0>)
# tensor(1.6043, grad_fn=<SumBackward0>)
# tensor(1.5970, grad_fn=<SumBackward0>)
# tensor(1.5711, grad_fn=<SumBackward0>)
# tensor(1.6063, grad_fn=<SumBackward0>)
# tensor(1.5881, grad_fn=<SumBackward0>)
# tensor(1.5812, grad_fn=<SumBackward0>)
# tensor(1.5940, grad_fn=<SumBackward0>)
# tensor(1.5930, grad_fn=<SumBackward0>)
# tensor(1.5641, grad_fn=<SumBackward0>)
# tensor(1.5724, grad_fn=<SumBackward0>)
# tensor(1.5717, grad_fn=<SumBackward0>)
# tensor(1.5799, grad_fn=<SumBackward0>)
# tensor(1.5801, grad_fn=<SumBackward0>)
# tensor(1.5704, grad_fn=<SumBackward0>)
# tensor(1.5876, grad_fn=<SumBackward0>)
# tensor(1.5993, grad_fn=<SumBackward0>)
# tensor(1.5745, grad_fn=<SumBackward0>)
# tensor(1.5791, grad_fn=<SumBackward0>)
# tensor(1.5670, grad_fn=<SumBackward0>)
# tensor(1.5656, grad_fn=<SumBackward0>)
# tensor(1.5594, grad_fn=<SumBackward0>)
# tensor(1.5688, grad_fn=<SumBackward0>)
# tensor(1.5715, grad_fn=<SumBackward0>)
# tensor(1.5646, grad_fn=<SumBackward0>)
# tensor(1.5669, grad_fn=<SumBackward0>)
# tensor(1.5656, grad_fn=<SumBackward0>)
# tensor(1.5657, grad_fn=<SumBackward0>)
# tensor(1.5841, grad_fn=<SumBackward0>)
# tensor(1.5601, grad_fn=<SumBackward0>)
# tensor(1.5389, grad_fn=<SumBackward0>)
# tensor(1.5517, grad_fn=<SumBackward0>)
# tensor(1.5578, grad_fn=<SumBackward0>)
# tensor(1.5639, grad_fn=<SumBackward0>)
# tensor(1.5620, grad_fn=<SumBackward0>)
# tensor(1.5613, grad_fn=<SumBackward0>)
# tensor(1.5486, grad_fn=<SumBackward0>)
# tensor(1.5540, grad_fn=<SumBackward0>)
# tensor(1.5312, grad_fn=<SumBackward0>)
# tensor(1.5586, grad_fn=<SumBackward0>)
# tensor(1.5627, grad_fn=<SumBackward0>)
# tensor(1.5534, grad_fn=<SumBackward0>)
# tensor(1.5500, grad_fn=<SumBackward0>)
# tensor(1.5540, grad_fn=<SumBackward0>)
# tensor(1.5486, grad_fn=<SumBackward0>)
# tensor(1.5444, grad_fn=<SumBackward0>)
# tensor(1.5297, grad_fn=<SumBackward0>)
# tensor(1.5726, grad_fn=<SumBackward0>)
# tensor(1.5494, grad_fn=<SumBackward0>)
# tensor(1.5320, grad_fn=<SumBackward0>)
# tensor(1.5463, grad_fn=<SumBackward0>)
# tensor(1.5536, grad_fn=<SumBackward0>)
# tensor(1.5286, grad_fn=<SumBackward0>)
# tensor(1.5388, grad_fn=<SumBackward0>)
# tensor(1.5509, grad_fn=<SumBackward0>)
# tensor(1.5223, grad_fn=<SumBackward0>)
# tensor(1.5379, grad_fn=<SumBackward0>)
# tensor(1.5291, grad_fn=<SumBackward0>)
# tensor(1.5262, grad_fn=<SumBackward0>)
# tensor(1.5278, grad_fn=<SumBackward0>)
# tensor(1.5389, grad_fn=<SumBackward0>)
# tensor(1.5352, grad_fn=<SumBackward0>)
# tensor(1.5115, grad_fn=<SumBackward0>)
# tensor(1.5184, grad_fn=<SumBackward0>)
# tensor(1.5240, grad_fn=<SumBackward0>)
# tensor(1.5206, grad_fn=<SumBackward0>)
# tensor(1.5196, grad_fn=<SumBackward0>)
# tensor(1.5109, grad_fn=<SumBackward0>)
# tensor(1.5237, grad_fn=<SumBackward0>)
# tensor(1.5220, grad_fn=<SumBackward0>)
# tensor(1.5258, grad_fn=<SumBackward0>)
# tensor(1.5121, grad_fn=<SumBackward0>)
# tensor(1.5281, grad_fn=<SumBackward0>)
# tensor(1.5019, grad_fn=<SumBackward0>)
# tensor(1.5130, grad_fn=<SumBackward0>)
# tensor(1.5348, grad_fn=<SumBackward0>)
# tensor(1.5066, grad_fn=<SumBackward0>)
# tensor(1.5102, grad_fn=<SumBackward0>)
# tensor(1.5058, grad_fn=<SumBackward0>)
# tensor(1.4987, grad_fn=<SumBackward0>)
# tensor(1.5042, grad_fn=<SumBackward0>)
# tensor(1.5199, grad_fn=<SumBackward0>)
# tensor(1.5081, grad_fn=<SumBackward0>)
# tensor(1.5040, grad_fn=<SumBackward0>)
# tensor(1.5192, grad_fn=<SumBackward0>)
# tensor(1.4906, grad_fn=<SumBackward0>)
# tensor(1.5155, grad_fn=<SumBackward0>)
# tensor(1.5152, grad_fn=<SumBackward0>)
# tensor(1.5136, grad_fn=<SumBackward0>)
# tensor(1.4868, grad_fn=<SumBackward0>)
# tensor(1.4929, grad_fn=<SumBackward0>)
# tensor(1.4931, grad_fn=<SumBackward0>)
# tensor(1.4963, grad_fn=<SumBackward0>)
# tensor(1.4787, grad_fn=<SumBackward0>)
# tensor(1.4954, grad_fn=<SumBackward0>)
# tensor(1.4814, grad_fn=<SumBackward0>)
# tensor(1.4991, grad_fn=<SumBackward0>)
# tensor(1.4996, grad_fn=<SumBackward0>)
# tensor(1.4999, grad_fn=<SumBackward0>)
# tensor(1.4777, grad_fn=<SumBackward0>)
# tensor(1.4882, grad_fn=<SumBackward0>)
# tensor(1.4872, grad_fn=<SumBackward0>)
# tensor(1.5018, grad_fn=<SumBackward0>)
# tensor(1.4981, grad_fn=<SumBackward0>)
# tensor(1.4651, grad_fn=<SumBackward0>)
# tensor(1.4684, grad_fn=<SumBackward0>)
# tensor(1.4734, grad_fn=<SumBackward0>)
# tensor(1.4667, grad_fn=<SumBackward0>)
# tensor(1.4470, grad_fn=<SumBackward0>)
# tensor(1.4752, grad_fn=<SumBackward0>)
# tensor(1.4921, grad_fn=<SumBackward0>)
# tensor(1.4852, grad_fn=<SumBackward0>)
# tensor(1.4612, grad_fn=<SumBackward0>)
# tensor(1.4674, grad_fn=<SumBackward0>)
# tensor(1.4574, grad_fn=<SumBackward0>)
# tensor(1.4819, grad_fn=<SumBackward0>)
# tensor(1.4685, grad_fn=<SumBackward0>)
# tensor(1.4726, grad_fn=<SumBackward0>)
# tensor(1.4745, grad_fn=<SumBackward0>)
# tensor(1.4537, grad_fn=<SumBackward0>)
# tensor(1.4827, grad_fn=<SumBackward0>)
# tensor(1.4671, grad_fn=<SumBackward0>)
# tensor(1.4657, grad_fn=<SumBackward0>)
# tensor(1.4614, grad_fn=<SumBackward0>)
# tensor(1.4574, grad_fn=<SumBackward0>)
# tensor(1.4520, grad_fn=<SumBackward0>)
# tensor(1.4810, grad_fn=<SumBackward0>)
# tensor(1.4641, grad_fn=<SumBackward0>)
# tensor(1.4437, grad_fn=<SumBackward0>)
# tensor(1.4562, grad_fn=<SumBackward0>)
# tensor(1.4419, grad_fn=<SumBackward0>)
# tensor(1.4431, grad_fn=<SumBackward0>)
# tensor(1.4688, grad_fn=<SumBackward0>)
# tensor(1.4753, grad_fn=<SumBackward0>)
# tensor(1.4503, grad_fn=<SumBackward0>)
# tensor(1.4332, grad_fn=<SumBackward0>)
# tensor(1.4602, grad_fn=<SumBackward0>)
# tensor(1.4309, grad_fn=<SumBackward0>)
# tensor(1.4507, grad_fn=<SumBackward0>)
# tensor(1.4305, grad_fn=<SumBackward0>)
# tensor(1.4616, grad_fn=<SumBackward0>)
# tensor(1.4642, grad_fn=<SumBackward0>)
# tensor(1.4463, grad_fn=<SumBackward0>)
# tensor(1.4373, grad_fn=<SumBackward0>)
# tensor(1.4554, grad_fn=<SumBackward0>)
# tensor(1.4222, grad_fn=<SumBackward0>)
# tensor(1.4347, grad_fn=<SumBackward0>)
# tensor(1.4422, grad_fn=<SumBackward0>)
# tensor(1.4297, grad_fn=<SumBackward0>)
# tensor(1.4304, grad_fn=<SumBackward0>)
# tensor(1.4446, grad_fn=<SumBackward0>)
# tensor(1.4315, grad_fn=<SumBackward0>)
# tensor(1.4394, grad_fn=<SumBackward0>)
# tensor(1.4461, grad_fn=<SumBackward0>)
# tensor(1.4077, grad_fn=<SumBackward0>)
# tensor(1.4365, grad_fn=<SumBackward0>)
# tensor(1.4319, grad_fn=<SumBackward0>)
# tensor(1.4433, grad_fn=<SumBackward0>)
# tensor(1.4287, grad_fn=<SumBackward0>)
# tensor(1.4231, grad_fn=<SumBackward0>)
# tensor(1.4234, grad_fn=<SumBackward0>)
# tensor(1.4311, grad_fn=<SumBackward0>)
# tensor(1.4277, grad_fn=<SumBackward0>)
# tensor(1.4386, grad_fn=<SumBackward0>)
# tensor(1.4269, grad_fn=<SumBackward0>)
# tensor(1.4114, grad_fn=<SumBackward0>)
# tensor(1.4132, grad_fn=<SumBackward0>)
# tensor(1.4250, grad_fn=<SumBackward0>)
# tensor(1.4112, grad_fn=<SumBackward0>)
# tensor(1.4388, grad_fn=<SumBackward0>)
# tensor(1.4081, grad_fn=<SumBackward0>)
# tensor(1.4040, grad_fn=<SumBackward0>)
# tensor(1.4146, grad_fn=<SumBackward0>)
# tensor(1.4100, grad_fn=<SumBackward0>)
# tensor(1.4082, grad_fn=<SumBackward0>)
# tensor(1.4144, grad_fn=<SumBackward0>)
# tensor(1.4151, grad_fn=<SumBackward0>)
# tensor(1.3980, grad_fn=<SumBackward0>)
# tensor(1.4306, grad_fn=<SumBackward0>)
# tensor(1.4145, grad_fn=<SumBackward0>)
# tensor(1.4147, grad_fn=<SumBackward0>)
# tensor(1.3952, grad_fn=<SumBackward0>)
# tensor(1.3908, grad_fn=<SumBackward0>)
# tensor(1.3887, grad_fn=<SumBackward0>)
# tensor(1.4114, grad_fn=<SumBackward0>)
# tensor(1.4138, grad_fn=<SumBackward0>)
# tensor(1.4069, grad_fn=<SumBackward0>)
# tensor(1.4149, grad_fn=<SumBackward0>)
# tensor(1.3903, grad_fn=<SumBackward0>)
# tensor(1.3911, grad_fn=<SumBackward0>)
# tensor(1.3937, grad_fn=<SumBackward0>)
# tensor(1.3893, grad_fn=<SumBackward0>)
# tensor(1.4024, grad_fn=<SumBackward0>)
# tensor(1.3966, grad_fn=<SumBackward0>)
# tensor(1.4086, grad_fn=<SumBackward0>)
# tensor(1.4057, grad_fn=<SumBackward0>)
# tensor(1.3758, grad_fn=<SumBackward0>)
# tensor(1.3935, grad_fn=<SumBackward0>)
# tensor(1.3690, grad_fn=<SumBackward0>)
# tensor(1.3990, grad_fn=<SumBackward0>)
# tensor(1.3810, grad_fn=<SumBackward0>)
# tensor(1.3754, grad_fn=<SumBackward0>)
# tensor(1.3878, grad_fn=<SumBackward0>)
# tensor(1.3756, grad_fn=<SumBackward0>)
# tensor(1.3692, grad_fn=<SumBackward0>)
# tensor(1.3884, grad_fn=<SumBackward0>)
# tensor(1.3810, grad_fn=<SumBackward0>)
# tensor(1.3825, grad_fn=<SumBackward0>)
# tensor(1.3706, grad_fn=<SumBackward0>)
# tensor(1.3824, grad_fn=<SumBackward0>)
# tensor(1.3723, grad_fn=<SumBackward0>)
# tensor(1.3636, grad_fn=<SumBackward0>)
# tensor(1.3813, grad_fn=<SumBackward0>)
# tensor(1.3964, grad_fn=<SumBackward0>)
# tensor(1.3720, grad_fn=<SumBackward0>)
# tensor(1.3571, grad_fn=<SumBackward0>)
# tensor(1.3898, grad_fn=<SumBackward0>)
# tensor(1.3685, grad_fn=<SumBackward0>)
# tensor(1.3813, grad_fn=<SumBackward0>)
# tensor(1.3725, grad_fn=<SumBackward0>)
# tensor(1.3721, grad_fn=<SumBackward0>)
# tensor(1.3833, grad_fn=<SumBackward0>)
# tensor(1.3458, grad_fn=<SumBackward0>)
# tensor(1.3544, grad_fn=<SumBackward0>)
# tensor(1.3474, grad_fn=<SumBackward0>)
# tensor(1.3791, grad_fn=<SumBackward0>)
# tensor(1.3668, grad_fn=<SumBackward0>)
# tensor(1.3731, grad_fn=<SumBackward0>)
# tensor(1.3742, grad_fn=<SumBackward0>)
# tensor(1.3480, grad_fn=<SumBackward0>)
# tensor(1.3717, grad_fn=<SumBackward0>)
# tensor(1.3577, grad_fn=<SumBackward0>)
# tensor(1.3600, grad_fn=<SumBackward0>)
# tensor(1.3583, grad_fn=<SumBackward0>)
# tensor(1.3632, grad_fn=<SumBackward0>)
# tensor(1.3466, grad_fn=<SumBackward0>)
# tensor(1.3582, grad_fn=<SumBackward0>)
# tensor(1.3710, grad_fn=<SumBackward0>)
# tensor(1.3635, grad_fn=<SumBackward0>)
# tensor(1.3556, grad_fn=<SumBackward0>)
# tensor(1.3319, grad_fn=<SumBackward0>)
# tensor(1.3517, grad_fn=<SumBackward0>)
# tensor(1.3469, grad_fn=<SumBackward0>)
# tensor(1.3605, grad_fn=<SumBackward0>)
# tensor(1.3484, grad_fn=<SumBackward0>)
# tensor(1.3513, grad_fn=<SumBackward0>)
# tensor(1.3599, grad_fn=<SumBackward0>)
# tensor(1.3423, grad_fn=<SumBackward0>)
# tensor(1.3537, grad_fn=<SumBackward0>)
# tensor(1.3448, grad_fn=<SumBackward0>)
# tensor(1.3498, grad_fn=<SumBackward0>)
# tensor(1.3321, grad_fn=<SumBackward0>)
# tensor(1.3251, grad_fn=<SumBackward0>)
# tensor(1.3432, grad_fn=<SumBackward0>)
# tensor(1.3314, grad_fn=<SumBackward0>)
# tensor(1.3275, grad_fn=<SumBackward0>)
# tensor(1.3460, grad_fn=<SumBackward0>)
# tensor(1.3447, grad_fn=<SumBackward0>)
# tensor(1.3367, grad_fn=<SumBackward0>)
# tensor(1.3345, grad_fn=<SumBackward0>)
# tensor(1.3184, grad_fn=<SumBackward0>)
# tensor(1.3214, grad_fn=<SumBackward0>)
# tensor(1.3104, grad_fn=<SumBackward0>)
# tensor(1.3402, grad_fn=<SumBackward0>)
# tensor(1.3303, grad_fn=<SumBackward0>)
# tensor(1.3207, grad_fn=<SumBackward0>)
# tensor(1.3162, grad_fn=<SumBackward0>)
# tensor(1.3331, grad_fn=<SumBackward0>)
# tensor(1.3425, grad_fn=<SumBackward0>)
# tensor(1.3078, grad_fn=<SumBackward0>)
# tensor(1.3390, grad_fn=<SumBackward0>)
# tensor(1.3326, grad_fn=<SumBackward0>)
# tensor(1.3295, grad_fn=<SumBackward0>)
# tensor(1.3166, grad_fn=<SumBackward0>)
# tensor(1.3331, grad_fn=<SumBackward0>)
# tensor(1.3349, grad_fn=<SumBackward0>)
# tensor(1.3329, grad_fn=<SumBackward0>)
# tensor(1.3230, grad_fn=<SumBackward0>)
# tensor(1.3253, grad_fn=<SumBackward0>)
# tensor(1.3289, grad_fn=<SumBackward0>)
# tensor(1.3065, grad_fn=<SumBackward0>)
# tensor(1.3197, grad_fn=<SumBackward0>)
# tensor(1.2963, grad_fn=<SumBackward0>)
# tensor(1.3135, grad_fn=<SumBackward0>)
# tensor(1.3413, grad_fn=<SumBackward0>)
# tensor(1.3025, grad_fn=<SumBackward0>)
# tensor(1.3171, grad_fn=<SumBackward0>)
# tensor(1.3234, grad_fn=<SumBackward0>)
# tensor(1.2999, grad_fn=<SumBackward0>)
# tensor(1.3105, grad_fn=<SumBackward0>)
# tensor(1.3245, grad_fn=<SumBackward0>)
# tensor(1.3102, grad_fn=<SumBackward0>)
# tensor(1.2912, grad_fn=<SumBackward0>)
# tensor(1.2885, grad_fn=<SumBackward0>)
# tensor(1.2995, grad_fn=<SumBackward0>)
# tensor(1.2931, grad_fn=<SumBackward0>)
# tensor(1.2928, grad_fn=<SumBackward0>)
# tensor(1.3200, grad_fn=<SumBackward0>)
# tensor(1.2781, grad_fn=<SumBackward0>)
# tensor(1.3000, grad_fn=<SumBackward0>)
# tensor(1.2968, grad_fn=<SumBackward0>)
# tensor(1.3061, grad_fn=<SumBackward0>)
# tensor(1.2965, grad_fn=<SumBackward0>)
# tensor(1.2954, grad_fn=<SumBackward0>)
# tensor(1.2958, grad_fn=<SumBackward0>)
# tensor(1.2839, grad_fn=<SumBackward0>)
# tensor(1.2953, grad_fn=<SumBackward0>)
# tensor(1.2950, grad_fn=<SumBackward0>)
# tensor(1.3018, grad_fn=<SumBackward0>)
# tensor(1.3145, grad_fn=<SumBackward0>)
# tensor(1.3093, grad_fn=<SumBackward0>)
# tensor(1.2911, grad_fn=<SumBackward0>)
# tensor(1.2910, grad_fn=<SumBackward0>)
# tensor(1.2822, grad_fn=<SumBackward0>)
# tensor(1.2986, grad_fn=<SumBackward0>)
# tensor(1.2847, grad_fn=<SumBackward0>)
# tensor(1.2908, grad_fn=<SumBackward0>)
# tensor(1.2938, grad_fn=<SumBackward0>)
# tensor(1.2827, grad_fn=<SumBackward0>)
# tensor(1.2792, grad_fn=<SumBackward0>)
# tensor(1.2578, grad_fn=<SumBackward0>)
# tensor(1.2690, grad_fn=<SumBackward0>)
# tensor(1.2860, grad_fn=<SumBackward0>)
# tensor(1.2682, grad_fn=<SumBackward0>)
# tensor(1.2579, grad_fn=<SumBackward0>)
# tensor(1.2661, grad_fn=<SumBackward0>)
# tensor(1.2754, grad_fn=<SumBackward0>)
# tensor(1.2640, grad_fn=<SumBackward0>)
# tensor(1.2791, grad_fn=<SumBackward0>)
# tensor(1.2787, grad_fn=<SumBackward0>)
# tensor(1.2591, grad_fn=<SumBackward0>)
# tensor(1.2748, grad_fn=<SumBackward0>)
# tensor(1.2848, grad_fn=<SumBackward0>)
# tensor(1.2829, grad_fn=<SumBackward0>)
# tensor(1.2543, grad_fn=<SumBackward0>)
# tensor(1.2669, grad_fn=<SumBackward0>)
# tensor(1.2680, grad_fn=<SumBackward0>)
# tensor(1.2644, grad_fn=<SumBackward0>)
# tensor(1.2811, grad_fn=<SumBackward0>)
# tensor(1.2693, grad_fn=<SumBackward0>)
# tensor(1.2723, grad_fn=<SumBackward0>)
# tensor(1.2734, grad_fn=<SumBackward0>)
# tensor(1.2600, grad_fn=<SumBackward0>)
# tensor(1.2582, grad_fn=<SumBackward0>)
# tensor(1.2716, grad_fn=<SumBackward0>)
# tensor(1.2568, grad_fn=<SumBackward0>)
# tensor(1.2619, grad_fn=<SumBackward0>)
# tensor(1.2605, grad_fn=<SumBackward0>)
# tensor(1.2472, grad_fn=<SumBackward0>)
# tensor(1.2632, grad_fn=<SumBackward0>)
# tensor(1.2503, grad_fn=<SumBackward0>)
# tensor(1.2610, grad_fn=<SumBackward0>)
# tensor(1.2554, grad_fn=<SumBackward0>)
# tensor(1.2640, grad_fn=<SumBackward0>)
# tensor(1.2588, grad_fn=<SumBackward0>)
# tensor(1.2666, grad_fn=<SumBackward0>)
# tensor(1.2519, grad_fn=<SumBackward0>)
# tensor(1.2341, grad_fn=<SumBackward0>)
# tensor(1.2641, grad_fn=<SumBackward0>)
# tensor(1.2366, grad_fn=<SumBackward0>)
# tensor(1.2741, grad_fn=<SumBackward0>)
# tensor(1.2445, grad_fn=<SumBackward0>)
# tensor(1.2400, grad_fn=<SumBackward0>)
# tensor(1.2467, grad_fn=<SumBackward0>)
# tensor(1.2648, grad_fn=<SumBackward0>)
# tensor(1.2423, grad_fn=<SumBackward0>)
# tensor(1.2439, grad_fn=<SumBackward0>)
# tensor(1.2373, grad_fn=<SumBackward0>)
# tensor(1.2257, grad_fn=<SumBackward0>)
# tensor(1.2464, grad_fn=<SumBackward0>)
# tensor(1.2273, grad_fn=<SumBackward0>)
# tensor(1.2745, grad_fn=<SumBackward0>)
# tensor(1.2451, grad_fn=<SumBackward0>)
# tensor(1.2434, grad_fn=<SumBackward0>)
# tensor(1.2299, grad_fn=<SumBackward0>)
# tensor(1.2433, grad_fn=<SumBackward0>)
# tensor(1.2390, grad_fn=<SumBackward0>)
# tensor(1.2516, grad_fn=<SumBackward0>)
# tensor(1.2275, grad_fn=<SumBackward0>)
# tensor(1.2471, grad_fn=<SumBackward0>)
# tensor(1.2443, grad_fn=<SumBackward0>)
# tensor(1.2309, grad_fn=<SumBackward0>)
# tensor(1.2195, grad_fn=<SumBackward0>)
# tensor(1.2358, grad_fn=<SumBackward0>)
# tensor(1.2433, grad_fn=<SumBackward0>)
# tensor(1.2073, grad_fn=<SumBackward0>)
# tensor(1.2315, grad_fn=<SumBackward0>)
# tensor(1.2394, grad_fn=<SumBackward0>)
# tensor(1.2292, grad_fn=<SumBackward0>)
# tensor(1.2409, grad_fn=<SumBackward0>)
# tensor(1.2273, grad_fn=<SumBackward0>)
# tensor(1.2200, grad_fn=<SumBackward0>)
# tensor(1.2172, grad_fn=<SumBackward0>)
# tensor(1.2269, grad_fn=<SumBackward0>)
# tensor(1.2205, grad_fn=<SumBackward0>)
# tensor(1.2025, grad_fn=<SumBackward0>)
# tensor(1.2262, grad_fn=<SumBackward0>)
# tensor(1.2289, grad_fn=<SumBackward0>)
# tensor(1.2085, grad_fn=<SumBackward0>)
# tensor(1.2160, grad_fn=<SumBackward0>)
# tensor(1.2100, grad_fn=<SumBackward0>)
# tensor(1.2248, grad_fn=<SumBackward0>)
# tensor(1.2190, grad_fn=<SumBackward0>)
# tensor(1.2049, grad_fn=<SumBackward0>)
# tensor(1.2198, grad_fn=<SumBackward0>)
# tensor(1.2158, grad_fn=<SumBackward0>)
# tensor(1.2322, grad_fn=<SumBackward0>)
# tensor(1.2048, grad_fn=<SumBackward0>)
# tensor(1.2131, grad_fn=<SumBackward0>)
# tensor(1.2261, grad_fn=<SumBackward0>)
# tensor(1.2086, grad_fn=<SumBackward0>)
# tensor(1.1999, grad_fn=<SumBackward0>)
# tensor(1.2019, grad_fn=<SumBackward0>)
# tensor(1.2079, grad_fn=<SumBackward0>)
# tensor(1.2340, grad_fn=<SumBackward0>)
# tensor(1.2117, grad_fn=<SumBackward0>)
# tensor(1.2021, grad_fn=<SumBackward0>)
# tensor(1.2217, grad_fn=<SumBackward0>)
# tensor(1.1838, grad_fn=<SumBackward0>)
# tensor(1.2093, grad_fn=<SumBackward0>)
# tensor(1.1889, grad_fn=<SumBackward0>)
# tensor(1.2035, grad_fn=<SumBackward0>)
# tensor(1.2003, grad_fn=<SumBackward0>)
# tensor(1.1962, grad_fn=<SumBackward0>)
# tensor(1.2032, grad_fn=<SumBackward0>)
# tensor(1.2001, grad_fn=<SumBackward0>)
# tensor(1.1943, grad_fn=<SumBackward0>)
# tensor(1.1866, grad_fn=<SumBackward0>)
# tensor(1.1956, grad_fn=<SumBackward0>)
# tensor(1.1889, grad_fn=<SumBackward0>)
# tensor(1.2000, grad_fn=<SumBackward0>)
# tensor(1.1918, grad_fn=<SumBackward0>)
# tensor(1.1951, grad_fn=<SumBackward0>)
# tensor(1.2018, grad_fn=<SumBackward0>)
# tensor(1.1995, grad_fn=<SumBackward0>)
# tensor(1.1844, grad_fn=<SumBackward0>)
# tensor(1.1953, grad_fn=<SumBackward0>)
# tensor(1.1934, grad_fn=<SumBackward0>)
# tensor(1.1946, grad_fn=<SumBackward0>)
# tensor(1.2043, grad_fn=<SumBackward0>)
# tensor(1.1857, grad_fn=<SumBackward0>)
# tensor(1.1766, grad_fn=<SumBackward0>)
# tensor(1.1879, grad_fn=<SumBackward0>)
# tensor(1.1880, grad_fn=<SumBackward0>)
# tensor(1.1709, grad_fn=<SumBackward0>)
# tensor(1.1855, grad_fn=<SumBackward0>)
# tensor(1.1865, grad_fn=<SumBackward0>)
# tensor(1.1708, grad_fn=<SumBackward0>)
# tensor(1.1846, grad_fn=<SumBackward0>)
# tensor(1.1721, grad_fn=<SumBackward0>)
# tensor(1.1798, grad_fn=<SumBackward0>)
# tensor(1.1823, grad_fn=<SumBackward0>)
# tensor(1.1703, grad_fn=<SumBackward0>)
# tensor(1.1613, grad_fn=<SumBackward0>)
# tensor(1.1722, grad_fn=<SumBackward0>)
# tensor(1.1741, grad_fn=<SumBackward0>)
# tensor(1.1749, grad_fn=<SumBackward0>)
# tensor(1.1757, grad_fn=<SumBackward0>)
# tensor(1.1799, grad_fn=<SumBackward0>)
# tensor(1.1727, grad_fn=<SumBackward0>)
# tensor(1.1635, grad_fn=<SumBackward0>)
# tensor(1.1749, grad_fn=<SumBackward0>)
# tensor(1.1803, grad_fn=<SumBackward0>)
# tensor(1.1552, grad_fn=<SumBackward0>)
# tensor(1.1546, grad_fn=<SumBackward0>)
# tensor(1.1647, grad_fn=<SumBackward0>)
# tensor(1.1885, grad_fn=<SumBackward0>)
# tensor(1.1844, grad_fn=<SumBackward0>)
# tensor(1.1713, grad_fn=<SumBackward0>)
# tensor(1.1601, grad_fn=<SumBackward0>)
# tensor(1.1655, grad_fn=<SumBackward0>)
# tensor(1.1512, grad_fn=<SumBackward0>)
# tensor(1.1763, grad_fn=<SumBackward0>)
# tensor(1.1726, grad_fn=<SumBackward0>)
# tensor(1.1599, grad_fn=<SumBackward0>)
# tensor(1.1749, grad_fn=<SumBackward0>)
# tensor(1.1553, grad_fn=<SumBackward0>)
# tensor(1.1595, grad_fn=<SumBackward0>)
# tensor(1.1706, grad_fn=<SumBackward0>)
# tensor(1.1557, grad_fn=<SumBackward0>)
# tensor(1.1711, grad_fn=<SumBackward0>)
# tensor(1.1651, grad_fn=<SumBackward0>)
# tensor(1.1574, grad_fn=<SumBackward0>)
# tensor(1.1491, grad_fn=<SumBackward0>)
# tensor(1.1672, grad_fn=<SumBackward0>)
# tensor(1.1732, grad_fn=<SumBackward0>)
# tensor(1.1641, grad_fn=<SumBackward0>)
# tensor(1.1427, grad_fn=<SumBackward0>)
# tensor(1.1585, grad_fn=<SumBackward0>)
# tensor(1.1517, grad_fn=<SumBackward0>)
# tensor(1.1438, grad_fn=<SumBackward0>)
# tensor(1.1471, grad_fn=<SumBackward0>)
# tensor(1.1466, grad_fn=<SumBackward0>)
# tensor(1.1507, grad_fn=<SumBackward0>)
# tensor(1.1413, grad_fn=<SumBackward0>)
# tensor(1.1339, grad_fn=<SumBackward0>)
# tensor(1.1359, grad_fn=<SumBackward0>)
# tensor(1.1602, grad_fn=<SumBackward0>)
# tensor(1.1403, grad_fn=<SumBackward0>)
# tensor(1.1397, grad_fn=<SumBackward0>)
# tensor(1.1475, grad_fn=<SumBackward0>)
# tensor(1.1353, grad_fn=<SumBackward0>)
# tensor(1.1400, grad_fn=<SumBackward0>)
# tensor(1.1634, grad_fn=<SumBackward0>)
# tensor(1.1322, grad_fn=<SumBackward0>)
# tensor(1.1437, grad_fn=<SumBackward0>)
# tensor(1.1506, grad_fn=<SumBackward0>)
# tensor(1.1526, grad_fn=<SumBackward0>)
# tensor(1.1400, grad_fn=<SumBackward0>)
# tensor(1.1295, grad_fn=<SumBackward0>)
# tensor(1.1301, grad_fn=<SumBackward0>)
# tensor(1.1306, grad_fn=<SumBackward0>)
# tensor(1.1341, grad_fn=<SumBackward0>)
# tensor(1.1199, grad_fn=<SumBackward0>)
# tensor(1.1204, grad_fn=<SumBackward0>)
# tensor(1.1599, grad_fn=<SumBackward0>)
# tensor(1.1283, grad_fn=<SumBackward0>)
# tensor(1.1186, grad_fn=<SumBackward0>)
# tensor(1.1431, grad_fn=<SumBackward0>)
# tensor(1.1387, grad_fn=<SumBackward0>)
# tensor(1.1222, grad_fn=<SumBackward0>)
# tensor(1.1306, grad_fn=<SumBackward0>)
# tensor(1.1356, grad_fn=<SumBackward0>)
# tensor(1.1400, grad_fn=<SumBackward0>)
# tensor(1.1379, grad_fn=<SumBackward0>)
# tensor(1.1350, grad_fn=<SumBackward0>)
# tensor(1.1239, grad_fn=<SumBackward0>)
# tensor(1.1210, grad_fn=<SumBackward0>)
# tensor(1.1370, grad_fn=<SumBackward0>)
# tensor(1.1243, grad_fn=<SumBackward0>)
# tensor(1.1217, grad_fn=<SumBackward0>)
# tensor(1.1390, grad_fn=<SumBackward0>)
# tensor(1.1160, grad_fn=<SumBackward0>)
# tensor(1.1112, grad_fn=<SumBackward0>)
# tensor(1.1225, grad_fn=<SumBackward0>)
# tensor(1.1140, grad_fn=<SumBackward0>)
# tensor(1.1274, grad_fn=<SumBackward0>)
# tensor(1.1355, grad_fn=<SumBackward0>)
# tensor(1.1511, grad_fn=<SumBackward0>)
# tensor(1.1172, grad_fn=<SumBackward0>)
# tensor(1.1245, grad_fn=<SumBackward0>)
# tensor(1.1341, grad_fn=<SumBackward0>)
# tensor(1.1011, grad_fn=<SumBackward0>)
# tensor(1.1161, grad_fn=<SumBackward0>)
# tensor(1.1117, grad_fn=<SumBackward0>)
# tensor(1.1074, grad_fn=<SumBackward0>)
# tensor(1.0901, grad_fn=<SumBackward0>)
# tensor(1.1351, grad_fn=<SumBackward0>)
# tensor(1.1021, grad_fn=<SumBackward0>)
# tensor(1.1232, grad_fn=<SumBackward0>)
# tensor(1.1093, grad_fn=<SumBackward0>)
# tensor(1.1101, grad_fn=<SumBackward0>)
# tensor(1.1195, grad_fn=<SumBackward0>)
# tensor(1.1103, grad_fn=<SumBackward0>)
# tensor(1.1089, grad_fn=<SumBackward0>)
# tensor(1.1024, grad_fn=<SumBackward0>)
# tensor(1.1088, grad_fn=<SumBackward0>)
# tensor(1.1266, grad_fn=<SumBackward0>)
# tensor(1.1020, grad_fn=<SumBackward0>)
# tensor(1.1080, grad_fn=<SumBackward0>)
# tensor(1.0908, grad_fn=<SumBackward0>)
# tensor(1.1231, grad_fn=<SumBackward0>)
# tensor(1.1112, grad_fn=<SumBackward0>)
# tensor(1.1057, grad_fn=<SumBackward0>)
# tensor(1.0994, grad_fn=<SumBackward0>)
# tensor(1.1003, grad_fn=<SumBackward0>)
# tensor(1.0981, grad_fn=<SumBackward0>)
# tensor(1.1082, grad_fn=<SumBackward0>)
# tensor(1.1073, grad_fn=<SumBackward0>)
# tensor(1.0789, grad_fn=<SumBackward0>)
# tensor(1.1149, grad_fn=<SumBackward0>)
# tensor(1.0997, grad_fn=<SumBackward0>)
# tensor(1.0884, grad_fn=<SumBackward0>)
# tensor(1.0940, grad_fn=<SumBackward0>)
# tensor(1.0966, grad_fn=<SumBackward0>)
# tensor(1.1073, grad_fn=<SumBackward0>)
# tensor(1.1066, grad_fn=<SumBackward0>)
# tensor(1.1184, grad_fn=<SumBackward0>)
# tensor(1.0952, grad_fn=<SumBackward0>)
# tensor(1.0784, grad_fn=<SumBackward0>)
# tensor(1.0986, grad_fn=<SumBackward0>)
# tensor(1.0859, grad_fn=<SumBackward0>)
# tensor(1.1045, grad_fn=<SumBackward0>)
# tensor(1.1070, grad_fn=<SumBackward0>)
# tensor(1.1129, grad_fn=<SumBackward0>)
# tensor(1.0955, grad_fn=<SumBackward0>)
# tensor(1.0839, grad_fn=<SumBackward0>)
# tensor(1.0861, grad_fn=<SumBackward0>)
# tensor(1.0904, grad_fn=<SumBackward0>)
# tensor(1.0912, grad_fn=<SumBackward0>)
# tensor(1.1143, grad_fn=<SumBackward0>)
# tensor(1.0932, grad_fn=<SumBackward0>)
# tensor(1.0811, grad_fn=<SumBackward0>)
# tensor(1.0849, grad_fn=<SumBackward0>)
# tensor(1.0719, grad_fn=<SumBackward0>)
# tensor(1.0766, grad_fn=<SumBackward0>)
# tensor(1.0934, grad_fn=<SumBackward0>)
# tensor(1.0722, grad_fn=<SumBackward0>)
# tensor(1.0818, grad_fn=<SumBackward0>)
# tensor(1.0917, grad_fn=<SumBackward0>)
# tensor(1.0758, grad_fn=<SumBackward0>)
# tensor(1.0832, grad_fn=<SumBackward0>)
# tensor(1.0707, grad_fn=<SumBackward0>)
# tensor(1.0768, grad_fn=<SumBackward0>)
# tensor(1.0866, grad_fn=<SumBackward0>)
# tensor(1.0781, grad_fn=<SumBackward0>)
# tensor(1.0732, grad_fn=<SumBackward0>)
# tensor(1.0878, grad_fn=<SumBackward0>)
# tensor(1.0822, grad_fn=<SumBackward0>)
# tensor(1.0959, grad_fn=<SumBackward0>)
# tensor(1.0638, grad_fn=<SumBackward0>)
# tensor(1.0894, grad_fn=<SumBackward0>)
# tensor(1.0870, grad_fn=<SumBackward0>)
# tensor(1.0655, grad_fn=<SumBackward0>)
# tensor(1.0573, grad_fn=<SumBackward0>)
# tensor(1.0617, grad_fn=<SumBackward0>)
# tensor(1.0669, grad_fn=<SumBackward0>)
# tensor(1.0730, grad_fn=<SumBackward0>)
# tensor(1.0721, grad_fn=<SumBackward0>)
# tensor(1.0811, grad_fn=<SumBackward0>)
# tensor(1.0959, grad_fn=<SumBackward0>)
# tensor(1.0890, grad_fn=<SumBackward0>)
# tensor(1.0667, grad_fn=<SumBackward0>)
# tensor(1.0763, grad_fn=<SumBackward0>)
# tensor(1.0635, grad_fn=<SumBackward0>)
# tensor(1.0799, grad_fn=<SumBackward0>)
# tensor(1.0598, grad_fn=<SumBackward0>)
# tensor(1.0472, grad_fn=<SumBackward0>)
# tensor(1.0587, grad_fn=<SumBackward0>)
# tensor(1.0645, grad_fn=<SumBackward0>)
# tensor(1.0749, grad_fn=<SumBackward0>)
# tensor(1.0595, grad_fn=<SumBackward0>)
# tensor(1.0546, grad_fn=<SumBackward0>)
# tensor(1.0475, grad_fn=<SumBackward0>)
# tensor(1.0559, grad_fn=<SumBackward0>)
# tensor(1.0689, grad_fn=<SumBackward0>)
# tensor(1.0877, grad_fn=<SumBackward0>)
# tensor(1.0762, grad_fn=<SumBackward0>)
# tensor(1.0659, grad_fn=<SumBackward0>)
# tensor(1.0686, grad_fn=<SumBackward0>)
# tensor(1.0559, grad_fn=<SumBackward0>)
# tensor(1.0806, grad_fn=<SumBackward0>)
# tensor(1.0692, grad_fn=<SumBackward0>)
# tensor(1.0493, grad_fn=<SumBackward0>)
# tensor(1.0592, grad_fn=<SumBackward0>)
# tensor(1.0563, grad_fn=<SumBackward0>)
# tensor(1.0700, grad_fn=<SumBackward0>)
# tensor(1.0647, grad_fn=<SumBackward0>)
# tensor(1.0615, grad_fn=<SumBackward0>)
# tensor(1.0570, grad_fn=<SumBackward0>)
# tensor(1.0402, grad_fn=<SumBackward0>)
# tensor(1.0449, grad_fn=<SumBackward0>)
# tensor(1.0351, grad_fn=<SumBackward0>)
# tensor(1.0549, grad_fn=<SumBackward0>)
# tensor(1.0630, grad_fn=<SumBackward0>)
# tensor(1.0840, grad_fn=<SumBackward0>)
# tensor(1.0593, grad_fn=<SumBackward0>)
# tensor(1.0552, grad_fn=<SumBackward0>)
# tensor(1.0555, grad_fn=<SumBackward0>)
# tensor(1.0318, grad_fn=<SumBackward0>)
# tensor(1.0405, grad_fn=<SumBackward0>)
# tensor(1.0671, grad_fn=<SumBackward0>)
# tensor(1.0571, grad_fn=<SumBackward0>)
# tensor(1.0443, grad_fn=<SumBackward0>)
# tensor(1.0415, grad_fn=<SumBackward0>)
# tensor(1.0352, grad_fn=<SumBackward0>)
# tensor(1.0295, grad_fn=<SumBackward0>)
# tensor(1.0541, grad_fn=<SumBackward0>)
# tensor(1.0556, grad_fn=<SumBackward0>)
# tensor(1.0360, grad_fn=<SumBackward0>)
# tensor(1.0724, grad_fn=<SumBackward0>)
# tensor(1.0526, grad_fn=<SumBackward0>)
# tensor(1.0313, grad_fn=<SumBackward0>)
# tensor(1.0477, grad_fn=<SumBackward0>)
# tensor(1.0342, grad_fn=<SumBackward0>)
# tensor(1.0535, grad_fn=<SumBackward0>)
# tensor(1.0543, grad_fn=<SumBackward0>)
# tensor(1.0507, grad_fn=<SumBackward0>)
# tensor(1.0370, grad_fn=<SumBackward0>)
# tensor(1.0442, grad_fn=<SumBackward0>)
# tensor(1.0458, grad_fn=<SumBackward0>)
# tensor(1.0375, grad_fn=<SumBackward0>)
# tensor(1.0457, grad_fn=<SumBackward0>)
# tensor(1.0337, grad_fn=<SumBackward0>)
# tensor(1.0344, grad_fn=<SumBackward0>)
# tensor(1.0555, grad_fn=<SumBackward0>)
# tensor(1.0321, grad_fn=<SumBackward0>)
# tensor(1.0394, grad_fn=<SumBackward0>)
# tensor(1.0490, grad_fn=<SumBackward0>)
# tensor(1.0290, grad_fn=<SumBackward0>)
# tensor(1.0321, grad_fn=<SumBackward0>)
# tensor(1.0378, grad_fn=<SumBackward0>)
# tensor(1.0325, grad_fn=<SumBackward0>)
# tensor(1.0318, grad_fn=<SumBackward0>)
# tensor(1.0268, grad_fn=<SumBackward0>)
# tensor(1.0224, grad_fn=<SumBackward0>)
# tensor(1.0413, grad_fn=<SumBackward0>)
# tensor(1.0297, grad_fn=<SumBackward0>)
# tensor(1.0129, grad_fn=<SumBackward0>)
# tensor(1.0167, grad_fn=<SumBackward0>)
# tensor(1.0340, grad_fn=<SumBackward0>)
# tensor(1.0334, grad_fn=<SumBackward0>)
# tensor(1.0257, grad_fn=<SumBackward0>)
# tensor(1.0318, grad_fn=<SumBackward0>)
# tensor(1.0209, grad_fn=<SumBackward0>)
# tensor(1.0171, grad_fn=<SumBackward0>)
# tensor(1.0266, grad_fn=<SumBackward0>)
# tensor(1.0132, grad_fn=<SumBackward0>)
# tensor(1.0305, grad_fn=<SumBackward0>)
# tensor(1.0213, grad_fn=<SumBackward0>)
# tensor(1.0043, grad_fn=<SumBackward0>)
# tensor(1.0101, grad_fn=<SumBackward0>)
# tensor(1.0322, grad_fn=<SumBackward0>)
# tensor(1.0274, grad_fn=<SumBackward0>)
# tensor(1.0229, grad_fn=<SumBackward0>)
# tensor(1.0125, grad_fn=<SumBackward0>)
# tensor(1.0215, grad_fn=<SumBackward0>)
# tensor(1.0208, grad_fn=<SumBackward0>)
# tensor(1.0127, grad_fn=<SumBackward0>)
# tensor(1.0169, grad_fn=<SumBackward0>)
# tensor(1.0248, grad_fn=<SumBackward0>)
# tensor(1.0281, grad_fn=<SumBackward0>)
# tensor(1.0175, grad_fn=<SumBackward0>)
# tensor(1.0197, grad_fn=<SumBackward0>)
# tensor(1.0287, grad_fn=<SumBackward0>)
# tensor(1.0251, grad_fn=<SumBackward0>)
# tensor(1.0188, grad_fn=<SumBackward0>)
# tensor(1.0138, grad_fn=<SumBackward0>)
# tensor(1.0394, grad_fn=<SumBackward0>)
# tensor(1.0034, grad_fn=<SumBackward0>)
# tensor(1.0287, grad_fn=<SumBackward0>)
# tensor(1.0205, grad_fn=<SumBackward0>)
# tensor(1.0168, grad_fn=<SumBackward0>)
# tensor(1.0300, grad_fn=<SumBackward0>)
# tensor(1.0235, grad_fn=<SumBackward0>)
# tensor(1.0162, grad_fn=<SumBackward0>)
# tensor(0.9999, grad_fn=<SumBackward0>)
# tensor(0.9977, grad_fn=<SumBackward0>)
# tensor(0.9922, grad_fn=<SumBackward0>)
# tensor(1.0241, grad_fn=<SumBackward0>)
# tensor(1.0136, grad_fn=<SumBackward0>)
# tensor(1.0146, grad_fn=<SumBackward0>)
# tensor(1.0015, grad_fn=<SumBackward0>)
# tensor(1.0211, grad_fn=<SumBackward0>)
# tensor(1.0087, grad_fn=<SumBackward0>)
# tensor(1.0039, grad_fn=<SumBackward0>)
# tensor(1.0040, grad_fn=<SumBackward0>)
# tensor(1.0200, grad_fn=<SumBackward0>)
# tensor(1.0128, grad_fn=<SumBackward0>)
# tensor(1.0292, grad_fn=<SumBackward0>)
# tensor(0.9984, grad_fn=<SumBackward0>)
# tensor(1.0062, grad_fn=<SumBackward0>)
# tensor(1.0014, grad_fn=<SumBackward0>)
# tensor(0.9906, grad_fn=<SumBackward0>)
# tensor(0.9878, grad_fn=<SumBackward0>)
# tensor(1.0145, grad_fn=<SumBackward0>)
# tensor(1.0251, grad_fn=<SumBackward0>)
# tensor(0.9991, grad_fn=<SumBackward0>)
# tensor(0.9978, grad_fn=<SumBackward0>)
# tensor(1.0133, grad_fn=<SumBackward0>)
# tensor(0.9894, grad_fn=<SumBackward0>)
# tensor(1.0050, grad_fn=<SumBackward0>)
# tensor(0.9921, grad_fn=<SumBackward0>)
# tensor(1.0027, grad_fn=<SumBackward0>)
# tensor(0.9814, grad_fn=<SumBackward0>)
# tensor(0.9942, grad_fn=<SumBackward0>)
# tensor(0.9963, grad_fn=<SumBackward0>)
# tensor(0.9787, grad_fn=<SumBackward0>)
# tensor(0.9963, grad_fn=<SumBackward0>)
# tensor(1.0033, grad_fn=<SumBackward0>)
# tensor(0.9815, grad_fn=<SumBackward0>)
# tensor(1.0044, grad_fn=<SumBackward0>)
# tensor(0.9728, grad_fn=<SumBackward0>)
# tensor(0.9803, grad_fn=<SumBackward0>)
# tensor(0.9902, grad_fn=<SumBackward0>)
# tensor(0.9914, grad_fn=<SumBackward0>)
# tensor(0.9816, grad_fn=<SumBackward0>)
# tensor(0.9898, grad_fn=<SumBackward0>)
# tensor(0.9815, grad_fn=<SumBackward0>)
# tensor(0.9944, grad_fn=<SumBackward0>)
# tensor(0.9905, grad_fn=<SumBackward0>)
# tensor(0.9907, grad_fn=<SumBackward0>)
# tensor(0.9804, grad_fn=<SumBackward0>)
# tensor(1.0096, grad_fn=<SumBackward0>)
# tensor(0.9861, grad_fn=<SumBackward0>)
# tensor(0.9901, grad_fn=<SumBackward0>)
# tensor(0.9849, grad_fn=<SumBackward0>)
# tensor(0.9791, grad_fn=<SumBackward0>)
# tensor(0.9788, grad_fn=<SumBackward0>)
# tensor(0.9843, grad_fn=<SumBackward0>)
# tensor(0.9772, grad_fn=<SumBackward0>)
# ...
# tensor(0.4548, grad_fn=<SumBackward0>)
# tensor(0.4497, grad_fn=<SumBackward0>)
# tensor(0.4491, grad_fn=<SumBackward0>)
# tensor(0.4500, grad_fn=<SumBackward0>)
# tensor(0.4571, grad_fn=<SumBackward0>)
# tensor(0.4562, grad_fn=<SumBackward0>)
# tensor(0.4526, grad_fn=<SumBackward0>)
# tensor(0.4535, grad_fn=<SumBackward0>)
# tensor(0.4552, grad_fn=<SumBackward0>)
# tensor(0.4424, grad_fn=<SumBackward0>)
# tensor(0.4543, grad_fn=<SumBackward0>)
# tensor(0.4462, grad_fn=<SumBackward0>)
# tensor(0.4557, grad_fn=<SumBackward0>)
# tensor(0.4567, grad_fn=<SumBackward0>)
# tensor(0.4496, grad_fn=<SumBackward0>)
# tensor(0.4518, grad_fn=<SumBackward0>)
# tensor(0.4474, grad_fn=<SumBackward0>)
# tensor(0.4530, grad_fn=<SumBackward0>)
# tensor(0.4589, grad_fn=<SumBackward0>)
# tensor(0.4507, grad_fn=<SumBackward0>)
# tensor(0.4490, grad_fn=<SumBackward0>)
# tensor(0.4543, grad_fn=<SumBackward0>)
# tensor(0.4526, grad_fn=<SumBackward0>)
# tensor(0.4491, grad_fn=<SumBackward0>)
# tensor(0.4457, grad_fn=<SumBackward0>)
# tensor(0.4478, grad_fn=<SumBackward0>)
# tensor(0.4593, grad_fn=<SumBackward0>)
# tensor(0.4492, grad_fn=<SumBackward0>)
# tensor(0.4522, grad_fn=<SumBackward0>)
# tensor(0.4432, grad_fn=<SumBackward0>)
# tensor(0.4466, grad_fn=<SumBackward0>)
# tensor(0.4598, grad_fn=<SumBackward0>)
# tensor(0.4621, grad_fn=<SumBackward0>)
# tensor(0.4504, grad_fn=<SumBackward0>)
# tensor(0.4489, grad_fn=<SumBackward0>)
# tensor(0.4553, grad_fn=<SumBackward0>)
# tensor(0.4512, grad_fn=<SumBackward0>)
# tensor(0.4550, grad_fn=<SumBackward0>)
# tensor(0.4548, grad_fn=<SumBackward0>)
# tensor(0.4542, grad_fn=<SumBackward0>)
# tensor(0.4476, grad_fn=<SumBackward0>)
# tensor(0.4505, grad_fn=<SumBackward0>)
# tensor(0.4514, grad_fn=<SumBackward0>)
# tensor(0.4574, grad_fn=<SumBackward0>)
# tensor(0.4523, grad_fn=<SumBackward0>)
# tensor(0.4577, grad_fn=<SumBackward0>)
# tensor(0.4556, grad_fn=<SumBackward0>)
# tensor(0.4584, grad_fn=<SumBackward0>)
# tensor(0.4488, grad_fn=<SumBackward0>)
# tensor(0.4519, grad_fn=<SumBackward0>)
# tensor(0.4536, grad_fn=<SumBackward0>)
# tensor(0.4437, grad_fn=<SumBackward0>)
# tensor(0.4556, grad_fn=<SumBackward0>)
# tensor(0.4417, grad_fn=<SumBackward0>)
# tensor(0.4563, grad_fn=<SumBackward0>)
# tensor(0.4492, grad_fn=<SumBackward0>)
# tensor(0.4489, grad_fn=<SumBackward0>)
# tensor(0.4519, grad_fn=<SumBackward0>)
# tensor(0.4472, grad_fn=<SumBackward0>)
# tensor(0.4518, grad_fn=<SumBackward0>)
# tensor(0.4488, grad_fn=<SumBackward0>)
# tensor(0.4545, grad_fn=<SumBackward0>)
# tensor(0.4456, grad_fn=<SumBackward0>)
# tensor(0.4672, grad_fn=<SumBackward0>)
# tensor(0.4502, grad_fn=<SumBackward0>)
# tensor(0.4559, grad_fn=<SumBackward0>)
# tensor(0.4577, grad_fn=<SumBackward0>)
# tensor(0.4560, grad_fn=<SumBackward0>)
# tensor(0.4547, grad_fn=<SumBackward0>)
# tensor(0.4468, grad_fn=<SumBackward0>)
# tensor(0.4480, grad_fn=<SumBackward0>)
# tensor(0.4513, grad_fn=<SumBackward0>)
# tensor(0.4415, grad_fn=<SumBackward0>)
# tensor(0.4544, grad_fn=<SumBackward0>)
# tensor(0.4565, grad_fn=<SumBackward0>)
# tensor(0.4522, grad_fn=<SumBackward0>)
# tensor(0.4437, grad_fn=<SumBackward0>)
# tensor(0.4398, grad_fn=<SumBackward0>)
# tensor(0.4490, grad_fn=<SumBackward0>)
# tensor(0.4507, grad_fn=<SumBackward0>)
# tensor(0.4515, grad_fn=<SumBackward0>)
# tensor(0.4463, grad_fn=<SumBackward0>)
# tensor(0.4540, grad_fn=<SumBackward0>)
# tensor(0.4526, grad_fn=<SumBackward0>)
# tensor(0.4529, grad_fn=<SumBackward0>)
# tensor(0.4505, grad_fn=<SumBackward0>)
# tensor(0.4572, grad_fn=<SumBackward0>)
# tensor(0.4468, grad_fn=<SumBackward0>)
# tensor(0.4504, grad_fn=<SumBackward0>)
# tensor(0.4498, grad_fn=<SumBackward0>)
# tensor(0.4490, grad_fn=<SumBackward0>)
# tensor(0.4502, grad_fn=<SumBackward0>)
# tensor(0.4523, grad_fn=<SumBackward0>)
# tensor(0.4503, grad_fn=<SumBackward0>)
# tensor(0.4558, grad_fn=<SumBackward0>)
# tensor(0.4499, grad_fn=<SumBackward0>)
# tensor(0.4519, grad_fn=<SumBackward0>)
# tensor(0.4517, grad_fn=<SumBackward0>)
# tensor(0.4515, grad_fn=<SumBackward0>)
# tensor(0.4601, grad_fn=<SumBackward0>)
# tensor(0.4495, grad_fn=<SumBackward0>)
# tensor(0.4544, grad_fn=<SumBackward0>)
# tensor(0.4495, grad_fn=<SumBackward0>)
# tensor(0.4500, grad_fn=<SumBackward0>)
# tensor(0.4469, grad_fn=<SumBackward0>)
# tensor(0.4585, grad_fn=<SumBackward0>)
# tensor(0.4570, grad_fn=<SumBackward0>)
# tensor(0.4529, grad_fn=<SumBackward0>)
# tensor(0.4424, grad_fn=<SumBackward0>)
# tensor(0.4502, grad_fn=<SumBackward0>)
# tensor(0.4410, grad_fn=<SumBackward0>)
# tensor(0.4533, grad_fn=<SumBackward0>)
# tensor(0.4477, grad_fn=<SumBackward0>)
# tensor(0.4453, grad_fn=<SumBackward0>)
# tensor(0.4449, grad_fn=<SumBackward0>)
# tensor(0.4494, grad_fn=<SumBackward0>)
# tensor(0.4610, grad_fn=<SumBackward0>)
# tensor(0.4543, grad_fn=<SumBackward0>)
# tensor(0.4447, grad_fn=<SumBackward0>)
# tensor(0.4494, grad_fn=<SumBackward0>)
# tensor(0.4476, grad_fn=<SumBackward0>)
# tensor(0.4387, grad_fn=<SumBackward0>)
# tensor(0.4507, grad_fn=<SumBackward0>)
# tensor(0.4483, grad_fn=<SumBackward0>)
# tensor(0.4430, grad_fn=<SumBackward0>)
# tensor(0.4577, grad_fn=<SumBackward0>)
# tensor(0.4541, grad_fn=<SumBackward0>)
# tensor(0.4512, grad_fn=<SumBackward0>)
# tensor(0.4584, grad_fn=<SumBackward0>)
# tensor(0.4517, grad_fn=<SumBackward0>)
# tensor(0.4418, grad_fn=<SumBackward0>)
# tensor(0.4443, grad_fn=<SumBackward0>)
# tensor(0.4516, grad_fn=<SumBackward0>)
# tensor(0.4508, grad_fn=<SumBackward0>)
# tensor(0.4437, grad_fn=<SumBackward0>)
# tensor(0.4591, grad_fn=<SumBackward0>)
# tensor(0.4502, grad_fn=<SumBackward0>)
# tensor(0.4580, grad_fn=<SumBackward0>)
# tensor(0.4481, grad_fn=<SumBackward0>)
# tensor(0.4511, grad_fn=<SumBackward0>)
# tensor(0.4537, grad_fn=<SumBackward0>)
# tensor(0.4549, grad_fn=<SumBackward0>)
# tensor(0.4447, grad_fn=<SumBackward0>)
# tensor(0.4520, grad_fn=<SumBackward0>)
# tensor(0.4534, grad_fn=<SumBackward0>)
# tensor(0.4464, grad_fn=<SumBackward0>)
# tensor(0.4566, grad_fn=<SumBackward0>)
# tensor(0.4493, grad_fn=<SumBackward0>)
# tensor(0.4525, grad_fn=<SumBackward0>)
# tensor(0.4529, grad_fn=<SumBackward0>)
# tensor(0.4475, grad_fn=<SumBackward0>)
# tensor(0.4563, grad_fn=<SumBackward0>)
# tensor(0.4463, grad_fn=<SumBackward0>)
# tensor(0.4477, grad_fn=<SumBackward0>)
# tensor(0.4567, grad_fn=<SumBackward0>)
# tensor(0.4457, grad_fn=<SumBackward0>)
# tensor(0.4468, grad_fn=<SumBackward0>)
# tensor(0.4539, grad_fn=<SumBackward0>)
# tensor(0.4431, grad_fn=<SumBackward0>)
# tensor(0.4519, grad_fn=<SumBackward0>)
# tensor(0.4585, grad_fn=<SumBackward0>)
# tensor(0.4484, grad_fn=<SumBackward0>)
# tensor(0.4535, grad_fn=<SumBackward0>)
# tensor(0.4545, grad_fn=<SumBackward0>)
# tensor(0.4467, grad_fn=<SumBackward0>)
# tensor(0.4557, grad_fn=<SumBackward0>)
# tensor(0.4479, grad_fn=<SumBackward0>)
# tensor(0.4432, grad_fn=<SumBackward0>)
# tensor(0.4507, grad_fn=<SumBackward0>)
# tensor(0.4538, grad_fn=<SumBackward0>)
# tensor(0.4556, grad_fn=<SumBackward0>)
# tensor(0.4549, grad_fn=<SumBackward0>)
# tensor(0.4523, grad_fn=<SumBackward0>)
# tensor(0.4532, grad_fn=<SumBackward0>)
# tensor(0.4595, grad_fn=<SumBackward0>)
# tensor(0.4445, grad_fn=<SumBackward0>)
# tensor(0.4556, grad_fn=<SumBackward0>)
# tensor(0.4539, grad_fn=<SumBackward0>)
# tensor(0.4541, grad_fn=<SumBackward0>)
# tensor(0.4504, grad_fn=<SumBackward0>)
# tensor(0.4539, grad_fn=<SumBackward0>)
# tensor(0.4516, grad_fn=<SumBackward0>)
# tensor(0.4441, grad_fn=<SumBackward0>)
# tensor(0.4502, grad_fn=<SumBackward0>)
# tensor(0.4587, grad_fn=<SumBackward0>)
# tensor(0.4532, grad_fn=<SumBackward0>)
# tensor(0.4573, grad_fn=<SumBackward0>)
# tensor(0.4501, grad_fn=<SumBackward0>)
# tensor(0.4473, grad_fn=<SumBackward0>)
# tensor(0.4425, grad_fn=<SumBackward0>)
# tensor(0.4552, grad_fn=<SumBackward0>)
# tensor(0.4500, grad_fn=<SumBackward0>)
# tensor(0.4479, grad_fn=<SumBackward0>)
# tensor(0.4545, grad_fn=<SumBackward0>)
# tensor(0.4500, grad_fn=<SumBackward0>)
# tensor(0.4551, grad_fn=<SumBackward0>)
# tensor(0.4454, grad_fn=<SumBackward0>)
# tensor(0.4486, grad_fn=<SumBackward0>)
# tensor(0.4471, grad_fn=<SumBackward0>)
# tensor(0.4471, grad_fn=<SumBackward0>)
# tensor(0.4637, grad_fn=<SumBackward0>)
# tensor(0.4519, grad_fn=<SumBackward0>)
# tensor(0.4474, grad_fn=<SumBackward0>)
# tensor(0.4485, grad_fn=<SumBackward0>)
# tensor(0.4522, grad_fn=<SumBackward0>)
# tensor(0.4562, grad_fn=<SumBackward0>)
# tensor(0.4544, grad_fn=<SumBackward0>)
# tensor(0.4506, grad_fn=<SumBackward0>)
# tensor(0.4498, grad_fn=<SumBackward0>)
# tensor(0.4533, grad_fn=<SumBackward0>)
# tensor(0.4496, grad_fn=<SumBackward0>)
# tensor(0.4439, grad_fn=<SumBackward0>)
# tensor(0.4464, grad_fn=<SumBackward0>)
# tensor(0.4524, grad_fn=<SumBackward0>)
# tensor(0.4549, grad_fn=<SumBackward0>)
# tensor(0.4505, grad_fn=<SumBackward0>)
# tensor(0.4503, grad_fn=<SumBackward0>)
# tensor(0.4449, grad_fn=<SumBackward0>)
# tensor(0.4499, grad_fn=<SumBackward0>)
# tensor(0.4483, grad_fn=<SumBackward0>)
# tensor(0.4441, grad_fn=<SumBackward0>)
# tensor(0.4465, grad_fn=<SumBackward0>)
# tensor(0.4406, grad_fn=<SumBackward0>)
# tensor(0.4534, grad_fn=<SumBackward0>)
# tensor(0.4503, grad_fn=<SumBackward0>)
# tensor(0.4481, grad_fn=<SumBackward0>)
# tensor(0.4510, grad_fn=<SumBackward0>)
# tensor(0.4460, grad_fn=<SumBackward0>)
# tensor(0.4514, grad_fn=<SumBackward0>)
# tensor(0.4399, grad_fn=<SumBackward0>)
# tensor(0.4536, grad_fn=<SumBackward0>)
# tensor(0.4478, grad_fn=<SumBackward0>)
# tensor(0.4488, grad_fn=<SumBackward0>)
# tensor(0.4468, grad_fn=<SumBackward0>)
# tensor(0.4437, grad_fn=<SumBackward0>)
# tensor(0.4528, grad_fn=<SumBackward0>)
# tensor(0.4485, grad_fn=<SumBackward0>)
# tensor(0.4409, grad_fn=<SumBackward0>)
# tensor(0.4425, grad_fn=<SumBackward0>)
# tensor(0.4467, grad_fn=<SumBackward0>)
# tensor(0.4457, grad_fn=<SumBackward0>)
# tensor(0.4484, grad_fn=<SumBackward0>)
# tensor(0.4438, grad_fn=<SumBackward0>)
# tensor(0.4430, grad_fn=<SumBackward0>)
# tensor(0.4549, grad_fn=<SumBackward0>)
# tensor(0.4499, grad_fn=<SumBackward0>)
# tensor(0.4448, grad_fn=<SumBackward0>)
# tensor(0.4474, grad_fn=<SumBackward0>)
# tensor(0.4514, grad_fn=<SumBackward0>)
# tensor(0.4407, grad_fn=<SumBackward0>)
# tensor(0.4552, grad_fn=<SumBackward0>)
# tensor(0.4557, grad_fn=<SumBackward0>)
# tensor(0.4523, grad_fn=<SumBackward0>)
# tensor(0.4521, grad_fn=<SumBackward0>)
# tensor(0.4553, grad_fn=<SumBackward0>)
# tensor(0.4495, grad_fn=<SumBackward0>)
# tensor(0.4444, grad_fn=<SumBackward0>)
# tensor(0.4491, grad_fn=<SumBackward0>)
# tensor(0.4466, grad_fn=<SumBackward0>)
# tensor(0.4464, grad_fn=<SumBackward0>)
# tensor(0.4549, grad_fn=<SumBackward0>)
# tensor(0.4549, grad_fn=<SumBackward0>)
# tensor(0.4481, grad_fn=<SumBackward0>)
# tensor(0.4511, grad_fn=<SumBackward0>)
# tensor(0.4513, grad_fn=<SumBackward0>)
# tensor(0.4498, grad_fn=<SumBackward0>)
# tensor(0.4527, grad_fn=<SumBackward0>)
# tensor(0.4529, grad_fn=<SumBackward0>)
# tensor(0.4527, grad_fn=<SumBackward0>)
# tensor(0.4419, grad_fn=<SumBackward0>)
# tensor(0.4560, grad_fn=<SumBackward0>)
# tensor(0.4465, grad_fn=<SumBackward0>)
# tensor(0.4506, grad_fn=<SumBackward0>)
# tensor(0.4550, grad_fn=<SumBackward0>)
# tensor(0.4534, grad_fn=<SumBackward0>)
# tensor(0.4433, grad_fn=<SumBackward0>)
# tensor(0.4537, grad_fn=<SumBackward0>)
# tensor(0.4445, grad_fn=<SumBackward0>)
# tensor(0.4438, grad_fn=<SumBackward0>)
# tensor(0.4505, grad_fn=<SumBackward0>)
# tensor(0.4425, grad_fn=<SumBackward0>)
# tensor(0.4465, grad_fn=<SumBackward0>)
# tensor(0.4470, grad_fn=<SumBackward0>)
# tensor(0.4469, grad_fn=<SumBackward0>)
# tensor(0.4438, grad_fn=<SumBackward0>)
# tensor(0.4430, grad_fn=<SumBackward0>)
# tensor(0.4407, grad_fn=<SumBackward0>)
# tensor(0.4454, grad_fn=<SumBackward0>)
# tensor(0.4538, grad_fn=<SumBackward0>)
# tensor(0.4540, grad_fn=<SumBackward0>)
# tensor(0.4425, grad_fn=<SumBackward0>)
# tensor(0.4453, grad_fn=<SumBackward0>)
# tensor(0.4420, grad_fn=<SumBackward0>)
# tensor(0.4476, grad_fn=<SumBackward0>)
# tensor(0.4434, grad_fn=<SumBackward0>)
# tensor(0.4428, grad_fn=<SumBackward0>)
# tensor(0.4366, grad_fn=<SumBackward0>)
# tensor(0.4586, grad_fn=<SumBackward0>)
# tensor(0.4354, grad_fn=<SumBackward0>)
# tensor(0.4493, grad_fn=<SumBackward0>)
# tensor(0.4405, grad_fn=<SumBackward0>)
# tensor(0.4496, grad_fn=<SumBackward0>)
# tensor(0.4443, grad_fn=<SumBackward0>)
# tensor(0.4549, grad_fn=<SumBackward0>)
# tensor(0.4578, grad_fn=<SumBackward0>)
# tensor(0.4454, grad_fn=<SumBackward0>)
# tensor(0.4445, grad_fn=<SumBackward0>)
# tensor(0.4486, grad_fn=<SumBackward0>)
# tensor(0.4496, grad_fn=<SumBackward0>)
# tensor(0.4467, grad_fn=<SumBackward0>)
# tensor(0.4549, grad_fn=<SumBackward0>)
# tensor(0.4431, grad_fn=<SumBackward0>)
# tensor(0.4437, grad_fn=<SumBackward0>)
# tensor(0.4445, grad_fn=<SumBackward0>)
# tensor(0.4488, grad_fn=<SumBackward0>)
# tensor(0.4593, grad_fn=<SumBackward0>)
# tensor(0.4518, grad_fn=<SumBackward0>)
# tensor(0.4582, grad_fn=<SumBackward0>)
# tensor(0.4519, grad_fn=<SumBackward0>)
# tensor(0.4604, grad_fn=<SumBackward0>)
# tensor(0.4489, grad_fn=<SumBackward0>)
# tensor(0.4459, grad_fn=<SumBackward0>)
# tensor(0.4481, grad_fn=<SumBackward0>)
# tensor(0.4559, grad_fn=<SumBackward0>)
# tensor(0.4446, grad_fn=<SumBackward0>)
# tensor(0.4430, grad_fn=<SumBackward0>)
# tensor(0.4483, grad_fn=<SumBackward0>)
# tensor(0.4483, grad_fn=<SumBackward0>)
# tensor(0.4407, grad_fn=<SumBackward0>)
# tensor(0.4479, grad_fn=<SumBackward0>)
# tensor(0.4463, grad_fn=<SumBackward0>)
# tensor(0.4447, grad_fn=<SumBackward0>)
# tensor(0.4506, grad_fn=<SumBackward0>)
# tensor(0.4566, grad_fn=<SumBackward0>)
# tensor(0.4505, grad_fn=<SumBackward0>)
# tensor(0.4446, grad_fn=<SumBackward0>)
# tensor(0.4551, grad_fn=<SumBackward0>)
# tensor(0.4506, grad_fn=<SumBackward0>)
# tensor(0.4514, grad_fn=<SumBackward0>)
# tensor(0.4512, grad_fn=<SumBackward0>)
# tensor(0.4431, grad_fn=<SumBackward0>)
# tensor(0.4371, grad_fn=<SumBackward0>)
# tensor(0.4475, grad_fn=<SumBackward0>)
# tensor(0.4500, grad_fn=<SumBackward0>)
# tensor(0.4404, grad_fn=<SumBackward0>)
# tensor(0.4436, grad_fn=<SumBackward0>)
# tensor(0.4439, grad_fn=<SumBackward0>)
# tensor(0.4394, grad_fn=<SumBackward0>)
# tensor(0.4537, grad_fn=<SumBackward0>)
# tensor(0.4513, grad_fn=<SumBackward0>)
# tensor(0.4406, grad_fn=<SumBackward0>)
# tensor(0.4510, grad_fn=<SumBackward0>)
# tensor(0.4546, grad_fn=<SumBackward0>)
# tensor(0.4426, grad_fn=<SumBackward0>)
# tensor(0.4441, grad_fn=<SumBackward0>)
# tensor(0.4445, grad_fn=<SumBackward0>)
# tensor(0.4381, grad_fn=<SumBackward0>)
# tensor(0.4513, grad_fn=<SumBackward0>)
# tensor(0.4549, grad_fn=<SumBackward0>)
# tensor(0.4485, grad_fn=<SumBackward0>)
# tensor(0.4416, grad_fn=<SumBackward0>)
# tensor(0.4463, grad_fn=<SumBackward0>)
# tensor(0.4539, grad_fn=<SumBackward0>)
# tensor(0.4495, grad_fn=<SumBackward0>)
# tensor(0.4502, grad_fn=<SumBackward0>)
# tensor(0.4411, grad_fn=<SumBackward0>)
# tensor(0.4450, grad_fn=<SumBackward0>)
# tensor(0.4504, grad_fn=<SumBackward0>)
# tensor(0.4459, grad_fn=<SumBackward0>)
# tensor(0.4420, grad_fn=<SumBackward0>)
# tensor(0.4527, grad_fn=<SumBackward0>)
# tensor(0.4497, grad_fn=<SumBackward0>)
# tensor(0.4434, grad_fn=<SumBackward0>)
# tensor(0.4526, grad_fn=<SumBackward0>)
# tensor(0.4538, grad_fn=<SumBackward0>)
# tensor(0.4478, grad_fn=<SumBackward0>)
# tensor(0.4416, grad_fn=<SumBackward0>)
# tensor(0.4465, grad_fn=<SumBackward0>)
# tensor(0.4536, grad_fn=<SumBackward0>)
# tensor(0.4410, grad_fn=<SumBackward0>)
# tensor(0.4488, grad_fn=<SumBackward0>)
# tensor(0.4405, grad_fn=<SumBackward0>)
# tensor(0.4474, grad_fn=<SumBackward0>)
# tensor(0.4432, grad_fn=<SumBackward0>)
# tensor(0.4493, grad_fn=<SumBackward0>)
# tensor(0.4421, grad_fn=<SumBackward0>)
# tensor(0.4514, grad_fn=<SumBackward0>)
# tensor(0.4423, grad_fn=<SumBackward0>)
# tensor(0.4413, grad_fn=<SumBackward0>)
# tensor(0.4490, grad_fn=<SumBackward0>)
# tensor(0.4443, grad_fn=<SumBackward0>)
# tensor(0.4348, grad_fn=<SumBackward0>)
# tensor(0.4398, grad_fn=<SumBackward0>)
# tensor(0.4476, grad_fn=<SumBackward0>)
# tensor(0.4479, grad_fn=<SumBackward0>)
# tensor(0.4457, grad_fn=<SumBackward0>)
# tensor(0.4488, grad_fn=<SumBackward0>)
# tensor(0.4471, grad_fn=<SumBackward0>)
# tensor(0.4447, grad_fn=<SumBackward0>)
# tensor(0.4467, grad_fn=<SumBackward0>)
# tensor(0.4430, grad_fn=<SumBackward0>)
# tensor(0.4450, grad_fn=<SumBackward0>)
# tensor(0.4434, grad_fn=<SumBackward0>)
# tensor(0.4400, grad_fn=<SumBackward0>)
# tensor(0.4572, grad_fn=<SumBackward0>)
# tensor(0.4438, grad_fn=<SumBackward0>)
# tensor(0.4517, grad_fn=<SumBackward0>)
# tensor([ 0.0174, -0.0168, -0.2737,  0.2559,  0.1510, -0.0227],
#        requires_grad=True)

# %%
# Input variables
x1 = torch.randn(100, 1)
x2 = torch.randn(100, 1)


# Output variable
y_noise = prediction_model(x1, x2, new_w)
y = (y_noise>0.5).float() # transform to binary data

# Plot data
scatter(x1[y==0], x2[y==0], c='b')
scatter(x1[y==1], x2[y==1], c='r')
contourf(X1, X2, Y, cmap='bwr', alpha=0.5)
scatter(x1, x2, c=y, cmap='bwr')
xlabel("$x_1$", fontsize=20)
ylabel("$x_2$", fontsize=20)
title('Nonlinear classification', size=20)
legend(['y = 0', 'y = 1'], prop={'size': 20})
